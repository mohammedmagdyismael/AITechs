# %% [markdown]
# ### In this session we'll try to implement word2vec NN for arabic text.

# %%
import numpy as np
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile
import time
from collections import Counter
import random
from math import sin
from bokeh.io import output_file, show , output_notebook
from bokeh.models import ColumnDataSource, HoverTool, LinearColorMapper
from bokeh.palettes import plasma
from bokeh.plotting import figure
import tensorflow as tf

# %%
import re
from collections import Counter

def preprocess(text):

    # Replace punctuation with tokens so we can use them in our model
    #text = text.replace('.', ' <PERIOD> ')
    text = text.replace(',', ' <COMMA> ')
    text = text.replace('"', ' <QUOTATION_MARK> ')
    text = text.replace(';', ' <SEMICOLON> ')
    text = text.replace('!', ' <EXCLAMATION_MARK> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    text = text.replace('(', ' <LEFT_PAREN> ')
    text = text.replace(')', ' <RIGHT_PAREN> ')
    text = text.replace('--', ' <HYPHENS> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    # text = text.replace('\n', ' <NEW_LINE> ')
    text = text.replace(':', ' <COLON> ')
    words = text.split()
    
    # Remove all words with  5 or fewer occurences
    word_counts = Counter(words)
    trimmed_words = [word for word in words if word_counts[word] >= 1]

    return trimmed_words

def get_batches(int_text, batch_size, seq_length):
    """
    Return batches of input and target
    :param int_text: Text with the words replaced by their ids
    :param batch_size: The size of batch
    :param seq_length: The length of sequence
    :return: A list where each item is a tuple of (batch of input, batch of target).
    """
    n_batches = int(len(int_text) / (batch_size * seq_length))

    # Drop the last few characters to make only full batches
    xdata = np.array(int_text[: n_batches * batch_size * seq_length])
    ydata = np.array(int_text[1: n_batches * batch_size * seq_length + 1])

    x_batches = np.split(xdata.reshape(batch_size, -1), n_batches, 1)
    y_batches = np.split(ydata.reshape(batch_size, -1), n_batches, 1)

    return list(zip(x_batches, y_batches))


def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: A tuple of dicts.  The first dict....
    """
    word_counts = Counter(words)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}

    return vocab_to_int, int_to_vocab

# %%
with open('./datasets/ara.txt') as f:
    text = f.read()

# %%
words = preprocess(text)

# %%
total_counts = Counter()

# %%
for i in range(len(words)):
    for word in words[i].split(" "):
        total_counts[word] += 1

# %%
total_counts.most_common()
# Out:
# [('من', 14529),
#  ('في', 13376),
#  ('إلى', 6927),
#  ('الرب', 6527),
#  ('على', 5831),
#  ('لا', 4895),
#  ('الله', 4608),
#  ('كل', 4367),
#  ('أن', 3625),
#  ('الذي', 3487),
#  ('ولا', 2991),
#  ('ما', 2887),
#  ('قد', 2723),
#  ('إسرائيل', 2520),
#  ('الذين', 2369),
#  ('هذا', 2203),
#  ('إن', 2082),
#  ('الأرض', 2076),
#  ('هو', 2025),
#  ('يا', 2013),
#  ('التي', 2012),
#  ('كان', 1974),
#  ('له', 1962),
#  ('لم', 1948),
#  ('عن', 1721),
#  ('الملك', 1662),
#  ('فقال', 1589),
#  ('ثم', 1578),
#  ('قال', 1569),
#  ('و', 1558),
#  ('أيضا', 1462),
#  ('لأن', 1458),
#  ('جميع', 1406),
#  ('بيت', 1341),
#  ('به', 1335),
#  ('أنا', 1330),
#  ('ذلك', 1324),
#  ('ومن', 1285),
#  ('لهم', 1281),
#  ('بن', 1262),
#  ('وقال', 1220),
#  ('مع', 1180),
#  ('وكان', 1160),
#  ('بل', 1147),
#  ('ملك', 1138),
#  ('حتى', 1137),
#  ('لأنه', 1132),
#  ('اليوم', 1119),
#  ('بني', 1114),
#  ('أو', 1069),
#  ('كما', 1051),
#  ('الأصحاح', 1050),
#  ('هذه', 1035),
#  ('الشعب', 1027),
#  ('عند', 1026),
#  ('لكم', 1009),
#  ('هكذا', 1003),
#  ('لي', 993),
#  ('يهوذا', 970),
#  ('الى', 969),
#  ('داود', 957),
#  ('بعد', 953),
#  ('ان', 911),
#  ('وكل', 908),
#  ('موسى', 904),
#  ('واحد', 870),
#  ('ولم', 857),
#  ('إلا', 857),
#  ('عليه', 852),
#  ('هناك', 825),
#  ('يكون', 804),
#  ('وما', 802),
#  ('رب', 791),
#  ('يسوع', 785),
#  ('أنت', 784),
#  ('أمام', 783),
#  ('إذا', 782),
#  ('وأما', 774),
#  ('قائلا', 774),
#  ('لك', 766),
#  ('يوم', 760),
#  ('وفي', 760),
#  ('أورشليم', 755),
#  ('ولكن', 747),
#  ('أرض', 746),
#  ('هم', 725),
#  ('ابن', 707),
#  ('ليس', 707),
#  ('فلا', 694),
#  ('حسب', 694),
#  ('هي', 691),
#  ('يقول', 688),
#  ('بين', 687),
#  ('لكي', 685),
#  ('عشر', 677),
#  ('بنو', 672),
#  ('فيها', 670),
#  ('المدينة', 662),
#  ('السماء', 637),
#  ('مصر', 636),
#  ('وهو', 630),
#  ('إذ', 625),
#  ('فيه', 620),
#  ('بها', 614),
#  ('شيء', 609),
#  ('وإن', 601),
#  ('عليهم', 583),
#  ('كانوا', 582),
#  ('فلما', 571),
#  ('إله', 570),
#  ('أيها', 567),
#  ('أما', 546),
#  ('للرب', 544),
#  ('الناس', 537),
#  ('وإذا', 533),
#  ('وعلى', 530),
#  ('المسيح', 521),
#  ('أيام', 512),
#  ('مئة', 510),
#  ('رجل', 506),
#  ('ولما', 505),
#  ('معه', 496),
#  ('أنتم', 481),
#  ('أجل', 474),
#  ('الإنسان', 473),
#  ('أنه', 470),
#  ('أحد', 454),
#  ('السماوات', 450),
#  ('منهم', 449),
#  ('إليه', 448),
#  ('لأني', 448),
#  ('سنة', 445),
#  ('مثل', 442),
#  ('بما', 437),
#  ('لها', 427),
#  ('فإن', 427),
#  ('قبل', 424),
#  ('لنا', 419),
#  ('الأمم', 417),
#  ('البيت', 407),
#  ('الكاهن', 406),
#  ('منه', 404),
#  ('الآن', 403),
#  ('كانت', 401),
#  ('لما', 400),
#  ('جدا', 397),
#  ('جاء', 396),
#  ('هوذا', 394),
#  ('كنت', 387),
#  ('هؤلاء', 387),
#  ('هل', 385),
#  ('شاول', 384),
#  ('تكون', 378),
#  ('عليك', 376),
#  ('لذلك', 374),
#  ('فلم', 374),
#  ('البحر', 372),
#  ('حين', 370),
#  ('يعقوب', 370),
#  ('الرجل', 369),
#  ('إني', 365),
#  ('إنه', 360),
#  ('تحت', 359),
#  ('نفسه', 356),
#  ('كثيرة', 355),
#  ('نحن', 354),
#  ('يد', 353),
#  ('إلهك', 353),
#  ('قل', 350),
#  ('عليها', 349),
#  ('قالوا', 349),
#  ('يكن', 347),
#  ('غير', 343),
#  ('عليكم', 339),
#  ('إلي', 339),
#  ('السيد', 338),
#  ('الحق', 333),
#  ('الشر', 332),
#  ('كلام', 331),
#  ('إنسان', 330),
#  ('لأنهم', 329),
#  ('أمر', 327),
#  ('تلك', 327),
#  ('الكهنة', 324),
#  ('بابل', 323),
#  ('وقد', 323),
#  ('لأجل', 318),
#  ('أم', 316),
#  ('عمل', 314),
#  ('نحو', 314),
#  ('وهم', 312),
#  ('وسط', 312),
#  ('اليهود', 310),
#  ('الأبد', 310),
#  ('شيئا', 309),
#  ('عنه', 308),
#  ('إليك', 306),
#  ('فرعون', 302),
#  ('والذين', 301),
#  ('عظيم', 300),
#  ('وأنا', 297),
#  ('الجنود', 297),
#  ('حينئذ', 293),
#  ('وجميع', 292),
#  ('لئلا', 290),
#  ('الثاني', 290),
#  ('النار', 287),
#  ('ذهب', 287),
#  ('امرأة', 286),
#  ('سليمان', 284),
#  ('علي', 284),
#  ('الكلام', 283),
#  ('جبل', 283),
#  ('الأيام', 282),
#  ('أني', 281),
#  ('كنتم', 281),
#  ('قائلين', 280),
#  ('آمنوا', 280),
#  ('عشرة', 276),
#  ('خير', 274),
#  ('إبراهيم', 274),
#  ('لماذا', 273),
#  ('مدينة', 271),
#  ('رجال', 271),
#  ('كذلك', 271),
#  ('السنة', 268),
#  ('منها', 268),
#  ('كيف', 267),
#  ('رئيس', 267),
#  ('والله', 266),
#  ('ماذا', 265),
#  ('الثالث', 262),
#  ('وجه', 262),
#  ('ابنه', 260),
#  ('نفسي', 259),
#  ('ويكون', 258),
#  ('لله', 257),
#  ('واحدة', 257),
#  ('رؤساء', 254),
#  ('بكل', 254),
#  ('لكن', 251),
#  ('الموت', 251),
#  ('عيني', 250),
#  ('يده', 250),
#  ('ولد', 250),
#  ('لأنك', 248),
#  ('يأتي', 246),
#  ('وإلى', 244),
#  ('اسمه', 243),
#  ('يوسف', 243),
#  ('طريق', 241),
#  ('إنما', 241),
#  ('باب', 241),
#  ('البرية', 240),
#  ('المذبح', 240),
#  ('الروح', 238),
#  ('والأرض', 237),
#  ('فأجاب', 235),
#  ('سمع', 235),
#  ('فمن', 234),
#  ('هارون', 233),
#  ('منكم', 232),
#  ('الجميع', 228),
#  ('حيث', 228),
#  ('يعلم', 227),
#  ('وليس', 226),
#  ('وقالوا', 226),
#  ('أقول', 226),
#  ('فوق', 225),
#  ('ماء', 224),
#  ('أكثر', 224),
#  ('ثلاثة', 224),
#  ('أبي', 223),
#  ('مما', 222),
#  ('الطريق', 222),
#  ('الأمر', 222),
#  ('ربك', 220),
#  ('صوت', 219),
#  ('الأول', 219),
#  ('تكلم', 218),
#  ('قدام', 215),
#  ('علينا', 215),
#  ('كلمة', 213),
#  ('الكتاب', 212),
#  ('واحدا', 211),
#  ('يدي', 210),
#  ('الشهر', 210),
#  ('الرابع', 210),
#  ('هأنذا', 210),
#  ('الشعوب', 209),
#  ('سيدي', 208),
#  ('وراء', 208),
#  ('سبعة', 208),
#  ('السابع', 207),
#  ('بيته', 206),
#  ('رأى', 206),
#  ('سبط', 206),
#  ('يشوع', 206),
#  ('بلا', 205),
#  ('منذ', 205),
#  ('آخر', 204),
#  ('الرجال', 204),
#  ('شعب', 203),
#  ('كثيرا', 203),
#  ('لكل', 203),
#  ('العالم', 203),
#  ('وكانت', 202),
#  ('بهم', 202),
#  ('الحياة', 202),
#  ('معك', 201),
#  ('إليكم', 199),
#  ('متى', 199),
#  ('قوم', 199),
#  ('النبي', 197),
#  ('والعشرون', 196),
#  ('القدس', 195),
#  ('الشمس', 195),
#  ('شعبي', 195),
#  ('فكان', 193),
#  ('إلهنا', 191),
#  ('فضة', 191),
#  ('ها', 191),
#  ('فقد', 190),
#  ('كفروا', 189),
#  ('وأنت', 188),
#  ('الحقل', 188),
#  ('معي', 188),
#  ('هنا', 187),
#  ('جهة', 187),
#  ('والآن', 186),
#  ('الجبال', 186),
#  ('أولئك', 185),
#  ('الباب', 184),
#  ('الخامس', 183),
#  ('يدك', 183),
#  ('بي', 181),
#  ('قلبه', 181),
#  ('عظيمة', 181),
#  ('آدم', 181),
#  ('فهو', 178),
#  ('بالله', 178),
#  ('إلهكم', 178),
#  ('ربنا', 178),
#  ('الليل', 177),
#  ('روح', 177),
#  ('خيمة', 177),
#  ('الأردن', 177),
#  ('أين', 176),
#  ('ذبيحة', 175),
#  ('الجبل', 175),
#  ('اسم', 175),
#  ('الفلسطينيين', 175),
#  ('ثلاث', 174),
#  ('أهل', 174),
#  ('لمن', 173),
#  ('كلها', 172),
#  ('صهيون', 171),
#  ('سفر', 171),
#  ('فإذا', 171),
#  ('أرسل', 171),
#  ('العظيم', 170),
#  ('صار', 168),
#  ('مدن', 167),
#  ('ألف', 167),
#  ('رجلا', 166),
#  ('المرأة', 166),
#  ('نفسك', 166),
#  ('فإنه', 166),
#  ('وإذ', 165),
#  ('الحكمة', 165),
#  ('يخرج', 165),
#  ('المياه', 165),
#  ('أنفسهم', 165),
#  ('اسرائيل', 164),
#  ('بهذا', 164),
#  ('موآب', 163),
#  ('وأخذ', 163),
#  ('قلت', 162),
#  ('سكان', 161),
#  ('كله', 161),
#  ('سبع', 161),
#  ('خرج', 160),
#  ('جميعا', 160),
#  ('الفضة', 159),
#  ('الهيكل', 159),
#  ('ألفا', 159),
#  ('رأس', 159),
#  ('نعمة', 159),
#  ('أفرايم', 158),
#  ('الحرب', 158),
#  ('لو', 157),
#  ('قلبك', 157),
#  ('الرحمن', 157),
#  ('وعمل', 157),
#  ('الذهب', 156),
#  ('بك', 156),
#  ('عذاب', 156),
#  ('إنا', 156),
#  ('قلوبهم', 155),
#  ('جعل', 155),
#  ('خارج', 154),
#  ('الرحيم', 154),
#  ('نفس', 154),
#  ('فما', 154),
#  ('لبني', 154),
#  ('قلب', 153),
#  ('للذين', 153),
#  ('لداود', 153),
#  ('عبدك', 153),
#  ('بنت', 152),
#  ('المزمور', 152),
#  ('ابني', 151),
#  ('بولس', 151),
#  ('الاجتماع', 151),
#  ('يسمع', 150),
#  ('فقالت', 149),
#  ('إليهم', 149),
#  ('معهم', 149),
#  ('وجهه', 148),
#  ('ولو', 148),
#  ('عنهم', 148),
#  ('السيف', 146),
#  ('السادس', 146),
#  ('وملك', 145),
#  ('نار', 145),
#  ('عبر', 145),
#  ('فعل', 145),
#  ('ألا', 145),
#  ('كثير', 145),
#  ('عظيما', 145),
#  ('وأن', 144),
#  ('وأنتم', 144),
#  ('أنهم', 144),
#  ('وبنو', 144),
#  ('الواحد', 143),
#  ('الموضع', 143),
#  ('الماء', 143),
#  ('معكم', 143),
#  ('أشور', 142),
#  ('وبعد', 142),
#  ('خطية', 142),
#  ('أنك', 141),
#  ('صنع', 141),
#  ('وهي', 141),
#  ('البر', 140),
#  ('معا', 140),
#  ('قلبي', 140),
#  ('بعض', 140),
#  ('أبيه', 140),
#  ('الإخوة', 139),
#  ('بالحق', 139),
#  ('مجد', 138),
#  ('ملوك', 138),
#  ('كنا', 138),
#  ('المدن', 138),
#  ('غضب', 137),
#  ('الثامن', 136),
#  ('يشاء', 136),
#  ('إلهي', 136),
#  ('بينهم', 136),
#  ('الارض', 135),
#  ('يفعل', 135),
#  ('لأنكم', 135),
#  ('الشمال', 135),
#  ('الأشرار', 134),
#  ('فان', 134),
#  ('مكان', 134),
#  ('دخل', 134),
#  ('وجاء', 134),
#  ('الجماعة', 134),
#  ('كثيرين', 134),
#  ('جلعاد', 133),
#  ('أمة', 132),
#  ('تكن', 132),
#  ('سنين', 132),
#  ('عني', 132),
#  ('آلهة', 132),
#  ('الناموس', 131),
#  ('بطرس', 131),
#  ('النساء', 131),
#  ('قوة', 131),
#  ('إرميا', 131),
#  ('ابنا', 130),
#  ('الشرير', 130),
#  ('منسى', 130),
#  ('بنيامين', 130),
#  ('وجعل', 130),
#  ('وقت', 130),
#  ('يأكل', 129),
#  ('علم', 129),
#  ('ولقد', 129),
#  ('شعبه', 129),
#  ('لان', 129),
#  ('ملكا', 128),
#  ('حي', 127),
#  ('الدهر', 127),
#  ('سمعت', 127),
#  ('سمعان', 127),
#  ('الآب', 127),
#  ('الجسد', 126),
#  ('ألم', 126),
#  ('بالسيف', 126),
#  ('والذي', 126),
#  ('تابوت', 126),
#  ('فخرج', 126),
#  ('عنده', 126),
#  ('يعمل', 126),
#  ('رأيت', 125),
#  ('وكلم', 125),
#  ('يوآب', 125),
#  ('دم', 125),
#  ('فإني', 124),
#  ('السامرة', 124),
#  ('يقولون', 124),
#  ('الوقت', 124),
#  ('بحسب', 124),
#  ('يدخل', 124),
#  ('لست', 123),
#  ('مات', 123),
#  ('آلاف', 123),
#  ('فقالوا', 123),
#  ('يوحنا', 122),
#  ('سورة', 122),
#  ('دون', 122),
#  ('يوجد', 122),
#  ('للملك', 121),
#  ('لن', 121),
#  ('سبيل', 121),
#  ('ذكر', 121),
#  ('أخرى', 121),
#  ('بالنار', 121),
#  ('صموئيل', 121),
#  ('بيد', 120),
#  ('قليلا', 120),
#  ('لأنها', 120),
#  ('الدنيا', 119),
#  ('المحلة', 119),
#  ('وكانوا', 119),
#  ('جانب', 119),
#  ('أولا', 119),
#  ('لأننا', 119),
#  ('ويل', 119),
#  ('أعلم', 119),
#  ('أي', 119),
#  ('النهر', 119),
#  ('أليس', 118),
#  ('القلب', 118),
#  ('الأنبياء', 118),
#  ('أخذ', 118),
#  ('المكان', 118),
#  ('خبزا', 118),
#  ('أرام', 117),
#  ('رأسه', 117),
#  ('وادي', 117),
#  ('يعلمون', 117),
#  ('تعلمون', 117),
#  ('فالآن', 117),
#  ('وقل', 117),
#  ('إليها', 117),
#  ('اذ', 117),
#  ('باسم', 117),
#  ('الشيطان', 116),
#  ('وهذه', 116),
#  ('بسم', 115),
#  ('سلام', 115),
#  ('إنك', 115),
#  ('التاسع', 114),
#  ('فأخذ', 114),
#  ('خمس', 114),
#  ('عينيك', 114),
#  ('أربعة', 114),
#  ('يموت', 114),
#  ('ربهم', 113),
#  ('العلي', 113),
#  ('عبيده', 113),
#  ('اللاويين', 113),
#  ('يتكلم', 113),
#  ('فأرسل', 113),
#  ('أدوم', 113),
#  ('الامم', 112),
#  ('تقول', 112),
#  ('الإصحاح', 112),
#  ('شر', 112),
#  ('شعبك', 112),
#  ('اذهب', 111),
#  ('حزقيا', 111),
#  ('سيد', 111),
#  ('عمون', 111),
#  ('كثيرون', 111),
#  ('النهار', 110),
#  ('أربع', 110),
#  ('حق', 110),
#  ('حياة', 110),
#  ('عليم', 110),
#  ('خلق', 110),
#  ('السبت', 110),
#  ('الإيمان', 109),
#  ('فيكون', 109),
#  ('اذا', 109),
#  ('وذهب', 109),
#  ('أيديهم', 109),
#  ('المساء', 109),
#  ('المقدس', 108),
#  ('خيرا', 108),
#  ('لنفسك', 108),
#  ('يوما', 108),
#  ('فجاء', 108),
#  ('الخطية', 108),
#  ('أمه', 108),
#  ('صارت', 107),
#  ('آبائهم', 107),
#  ('وتكون', 107),
#  ('لنفسه', 107),
#  ('الساعة', 106),
#  ('اما', 106),
#  ('كلم', 106),
#  ('الدم', 106),
#  ('المئة', 106),
#  ('جيش', 106),
#  ('الجنوب', 106),
#  ('المؤمنين', 105),
#  ('عنها', 105),
#  ('منك', 105),
#  ('الملوك', 105),
#  ('الحادي', 105),
#  ('عبيد', 104),
#  ('وأرسل', 104),
#  ('فقط', 104),
#  ('وهذا', 104),
#  ('أنزل', 104),
#  ('ملاك', 103),
#  ('جماعة', 103),
#  ('بسبب', 103),
#  ('يصنع', 103),
#  ('اورشليم', 103),
#  ('قام', 103),
#  ('الآخر', 103),
#  ('الصباح', 103),
#  ('ربكم', 103),
#  ('ملكوت', 102),
#  ('أمامك', 102),
#  ('عينيه', 101),
#  ('والثلاثون', 101),
#  ('وجد', 101),
#  ('تعملون', 101),
#  ('عوضا', 101),
#  ('إسحاق', 100),
#  ('تلاميذه', 100),
#  ('فقام', 100),
#  ('يقدر', 100),
#  ('وعشرين', 99),
#  ('فعلت', 99),
#  ('يؤمنون', 99),
#  ('وفيما', 99),
#  ('الشريعة', 99),
#  ('ايها', 99),
#  ('اليه', 99),
#  ('اسمك', 99),
#  ('يقتل', 99),
#  ('إنهم', 98),
#  ('مكانه', 98),
#  ('بكم', 98),
#  ('ينبغي', 98),
#  ('لحم', 98),
#  ('الإثم', 98),
#  ('وخرج', 98),
#  ('خمسة', 98),
#  ('الأمور', 98),
#  ('انه', 97),
#  ('الغنم', 97),
#  ('والرب', 97),
#  ('رحمة', 97),
#  ('اسمعوا', 97),
#  ('ربي', 97),
#  ('منا', 97),
#  ('الدار', 97),
#  ('يديه', 97),
#  ('ليست', 97),
#  ('بعضهم', 96),
#  ('يحب', 96),
#  ('جاءوا', 96),
#  ('رؤوس', 96),
#  ('وبيت', 96),
#  ('العذاب', 96),
#  ('امام', 95),
#  ('الصديق', 95),
#  ('بنات', 95),
#  ('وهارون', 95),
#  ('كلهم', 95),
#  ('يعرف', 95),
#  ('تأتي', 95),
#  ('الإله', 94),
#  ('شريعة', 94),
#  ('وعن', 94),
#  ('ذراعا', 94),
#  ('ست', 94),
#  ('وحده', 94),
#  ('أنكم', 94),
#  ('رحمته', 94),
#  ('عندما', 94),
#  ('عين', 93),
#  ('ومات', 93),
#  ('عشيرة', 93),
#  ('لهما', 93),
#  ('كنعان', 93),
#  ('أبشالوم', 93),
#  ('لجميع', 92),
#  ('القوم', 92),
#  ('أمامه', 92),
#  ('عيسو', 92),
#  ('خبز', 92),
#  ('تكلمت', 92),
#  ('بيتك', 92),
#  ('تعلم', 91),
#  ('مياه', 91),
#  ('أتى', 91),
#  ('المسكن', 91),
#  ('حكمة', 91),
#  ('عبد', 91),
#  ('أنفسكم', 91),
#  ('او', 91),
#  ('عهد', 91),
#  ('بغير', 90),
#  ('وجهك', 90),
#  ('يوناتان', 90),
#  ('الحكيم', 90),
#  ('داخل', 90),
#  ('المحرقة', 90),
#  ('فهم', 90),
#  ('الخير', 89),
#  ('الصلاة', 89),
#  ('آية', 89),
#  ('بعضا', 89),
#  ('بصوت', 89),
#  ('وعشرون', 89),
#  ('يربعام', 89),
#  ('وقالت', 89),
#  ('الكل', 88),
#  ('ونحن', 88),
#  ('ليلا', 88),
#  ('يوناثان', 88),
#  ('قول', 88),
#  ('عندك', 88),
#  ('أمامي', 88),
#  ('محرقة', 88),
#  ('فيك', 88),
#  ('نزل', 88),
#  ('فيما', 87),
#  ('معنا', 87),
#  ('نوح', 87),
#  ('فقلت', 87),
#  ('بينكم', 87),
#  ('إيليا', 87),
#  ('العهد', 86),
#  ('الجيش', 86),
#  ('أصحاب', 86),
#  ('فيكم', 86),
#  ('تخرج', 86),
#  ('فم', 86),
#  ('يرى', 86),
#  ('شرا', 86),
#  ('بقية', 85),
#  ('وضرب', 85),
#  ('النفس', 85),
#  ('نصيب', 85),
#  ('عنك', 85),
#  ('قلوبكم', 85),
#  ('نحاس', 85),
#  ('الأولى', 85),
#  ('جهنم', 84),
#  ('حسن', 84),
#  ('وكذلك', 84),
#  ('أذرع', 84),
#  ('الأموات', 84),
#  ('امرأته', 84),
#  ('مبين', 84),
#  ('جسد', 84),
#  ('ابنة', 84),
#  ('ههنا', 84),
#  ('امر', 84),
#  ('مرة', 83),
#  ('شيوخ', 83),
#  ('الحي', 83),
#  ('لدى', 83),
#  ('فانه', 83),
#  ('الكلمة', 82),
#  ('مريم', 82),
#  ('القيامة', 82),
#  ('يعملون', 82),
#  ('دائما', 82),
#  ('لبيت', 81),
#  ('أول', 81),
#  ('وهكذا', 81),
#  ('النور', 81),
#  ('صاحبه', 81),
#  ('إخوته', 81),
#  ('لقد', 81),
#  ('ودعا', 81),
#  ('تقدمة', 81),
#  ('عدد', 81),
#  ('واسم', 80),
#  ('فكيف', 80),
#  ('انا', 80),
#  ('بيوت', 80),
#  ('بالرب', 80),
#  ('لهذا', 80),
#  ('وصعد', 80),
#  ('ثيابه', 80),
#  ('أيتها', 80),
#  ('عشائرهم', 79),
#  ('نارا', 79),
#  ('شاء', 79),
#  ('أكون', 79),
#  ('قليل', 79),
#  ('وعند', 79),
#  ('مكتوب', 79),
#  ('ليد', 79),
#  ('إثم', 79),
#  ('الخمر', 79),
#  ('لموسى', 79),
#  ('الريح', 79),
#  ('قالت', 79),
#  ('ذراع', 79),
#  ('فتكون', 79),
#  ('ونزلوا', 79),
#  ('الغد', 78),
#  ('كتاب', 78),
#  ('أفعل', 78),
#  ('يطلب', 78),
#  ('الجمع', 78),
#  ('سلطان', 78),
#  ('عمله', 78),
#  ('إياها', 78),
#  ('عبيدك', 78),
#  ('صعد', 78),
#  ('اليهودية', 78),
#  ('تخم', 78),
#  ('فدعا', 77),
#  ('عنكم', 77),
#  ('فيهم', 77),
#  ('ارض', 77),
#  ('إيل', 77),
#  ('يقوم', 77),
#  ('عهدا', 77),
#  ('الدهور', 77),
#  ('موضع', 77),
#  ('أخآب', 77),
#  ('برية', 77),
#  ('السجن', 76),
#  ('شجرة', 76),
#  ('للناس', 76),
#  ('العظيمة', 76),
#  ('السلام', 76),
#  ('طوبيا', 76),
#  ('قرية', 76),
#  ('الرسول', 76),
#  ('الملائكة', 76),
#  ('الجليل', 76),
#  ('انظر', 75),
#  ('مني', 75),
#  ('صور', 75),
#  ('مذبح', 75),
#  ('وعد', 75),
#  ('وعملوا', 75),
#  ('سمعوا', 75),
#  ('القديسين', 75),
#  ('بيده', 75),
#  ('بكر', 75),
#  ('انت', 75),
#  ('قيل', 74),
#  ('عشرين', 74),
#  ('سلاه', 74),
#  ('أعظم', 74),
#  ('صنعت', 74),
#  ('قتل', 74),
#  ('بعيد', 74),
#  ('آيات', 74),
#  ('طوبى', 74),
#  ('الهاوية', 74),
#  ('بجميع', 73),
#  ('ربه', 73),
#  ('اسمي', 73),
#  ('وأتى', 73),
#  ('رجع', 73),
#  ('الأنهار', 73),
#  ('أربعين', 73),
#  ('بنيه', 73),
#  ('مبارك', 73),
#  ('حسنا', 73),
#  ('آبائه', 73),
#  ('أحدا', 73),
#  ('يرجع', 73),
#  ('آمين', 73),
#  ('ترى', 73),
#  ('أمور', 73),
#  ('قدامه', 72),
#  ('العدو', 72),
#  ('للشعب', 72),
#  ('الظالمين', 72),
#  ('تسمع', 72),
#  ('تأكل', 72),
#  ('العمل', 72),
#  ('الرسل', 72),
#  ('بشر', 72),
#  ('بأن', 72),
#  ('بعضكم', 72),
#  ('وجهي', 71),
#  ('أبيك', 71),
#  ('يسمعوا', 71),
#  ('اثنين', 71),
#  ('يقال', 71),
#  ('القتال', 71),
#  ('نور', 71),
#  ('غضبه', 71),
#  ('رحيم', 71),
#  ('حكيم', 71),
#  ('جعلت', 71),
#  ('الآخرة', 71),
#  ('لاوي', 71),
#  ('المغنين', 71),
#  ('سريعا', 71),
#  ('صالح', 70),
#  ('رأوبين', 70),
#  ('ايام', 70),
#  ('الرؤساء', 70),
#  ('قم', 70),
#  ('دانيآل', 70),
#  ('العزيز', 70),
#  ('نصف', 70),
#  ('الدين', 70),
#  ('رسول', 70),
#  ('حجارة', 70),
#  ('مقابل', 70),
#  ('تخف', 70),
#  ('يريد', 70),
#  ('الانسان', 69),
#  ('يجعل', 69),
#  ('للحرب', 69),
#  ('لانه', 69),
#  ('كن', 69),
#  ('وبقية', 69),
#  ('الملاك', 69),
#  ('خذ', 69),
#  ('حول', 69),
#  ('أبواب', 69),
#  ('إياه', 69),
#  ('الشرق', 69),
#  ('شديد', 69),
#  ('العاشر', 69),
#  ('ورؤساء', 69),
#  ('وأيضا', 69),
#  ('مرات', 68),
#  ('يذهب', 68),
#  ('قريب', 68),
#  ('ستة', 68),
#  ('القدير', 68),
#  ('إنها', 68),
#  ('جاد', 68),
#  ('كرسي', 68),
#  ('عندي', 68),
#  ('ملكه', 68),
#  ('وإخوته', 68),
#  ('فماذا', 68),
#  ('أخيه', 68),
#  ('فدخل', 68),
#  ('قدس', 67),
#  ('جنات', 67),
#  ('الخبز', 67),
#  ('كلا', 67),
#  ('ورسوله', 67),
#  ('الكلدانيين', 67),
#  ('رسلا', 67),
#  ('الزمان', 67),
#  ('المجد', 67),
#  ('تجري', 67),
#  ('أسباط', 67),
#  ('يسمعون', 67),
#  ('عما', 67),
#  ('فارس', 67),
#  ('دان', 66),
#  ('جئت', 66),
#  ('كلامي', 66),
#  ('الجنة', 66),
#  ('والأربعون', 66),
#  ('الثلاثة', 66),
#  ('خرجت', 66),
#  ('ذي', 66),
#  ('بسلام', 66),
#  ('بغتة', 66),
#  ('وصنع', 66),
#  ('إلها', 66),
#  ('نجسا', 66),
#  ('حبرون', 66),
#  ('تكونوا', 66),
#  ('حقا', 66),
#  ('أرسلني', 66),
#  ('يأخذ', 66),
#  ('وخمسة', 66),
#  ('فذهب', 66),
#  ('إلينا', 65),
#  ...]

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 578413
# Unique words: 74985

# %%
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
int_to_vocab
# Out:
# {0: 'من',
#  1: 'في',
#  2: 'إلى',
#  3: 'الرب',
#  4: 'على',
#  5: 'لا',
#  6: 'الله',
#  7: 'كل',
#  8: 'أن',
#  9: 'الذي',
#  10: 'ولا',
#  11: 'ما',
#  12: 'قد',
#  13: 'إسرائيل',
#  14: 'الذين',
#  15: 'هذا',
#  16: 'إن',
#  17: 'الأرض',
#  18: 'هو',
#  19: 'يا',
#  20: 'التي',
#  21: 'كان',
#  22: 'له',
#  23: 'لم',
#  24: 'عن',
#  25: 'الملك',
#  26: 'فقال',
#  27: 'ثم',
#  28: 'قال',
#  29: 'و',
#  30: 'أيضا',
#  31: 'لأن',
#  32: 'جميع',
#  33: 'بيت',
#  34: 'به',
#  35: 'أنا',
#  36: 'ذلك',
#  37: 'ومن',
#  38: 'لهم',
#  39: 'بن',
#  40: 'وقال',
#  41: 'مع',
#  42: 'وكان',
#  43: 'بل',
#  44: 'ملك',
#  45: 'حتى',
#  46: 'لأنه',
#  47: 'اليوم',
#  48: 'بني',
#  49: 'أو',
#  50: 'كما',
#  51: 'الأصحاح',
#  52: 'هذه',
#  53: 'الشعب',
#  54: 'عند',
#  55: 'لكم',
#  56: 'هكذا',
#  57: 'لي',
#  58: 'يهوذا',
#  59: 'الى',
#  60: 'داود',
#  61: 'بعد',
#  62: 'ان',
#  63: 'وكل',
#  64: 'موسى',
#  65: 'واحد',
#  66: 'ولم',
#  67: 'إلا',
#  68: 'عليه',
#  69: 'هناك',
#  70: 'يكون',
#  71: 'وما',
#  72: 'رب',
#  73: 'يسوع',
#  74: 'أنت',
#  75: 'أمام',
#  76: 'إذا',
#  77: 'وأما',
#  78: 'قائلا',
#  79: 'لك',
#  80: 'يوم',
#  81: 'وفي',
#  82: 'أورشليم',
#  83: 'ولكن',
#  84: 'أرض',
#  85: 'هم',
#  86: 'ابن',
#  87: 'ليس',
#  88: 'فلا',
#  89: 'حسب',
#  90: 'هي',
#  91: 'يقول',
#  92: 'بين',
#  93: 'لكي',
#  94: 'عشر',
#  95: 'بنو',
#  96: 'فيها',
#  97: 'المدينة',
#  98: 'السماء',
#  99: 'مصر',
#  100: 'وهو',
#  101: 'إذ',
#  102: 'فيه',
#  103: 'بها',
#  104: 'شيء',
#  105: 'وإن',
#  106: 'عليهم',
#  107: 'كانوا',
#  108: 'فلما',
#  109: 'إله',
#  110: 'أيها',
#  111: 'أما',
#  112: 'للرب',
#  113: 'الناس',
#  114: 'وإذا',
#  115: 'وعلى',
#  116: 'المسيح',
#  117: 'أيام',
#  118: 'مئة',
#  119: 'رجل',
#  120: 'ولما',
#  121: 'معه',
#  122: 'أنتم',
#  123: 'أجل',
#  124: 'الإنسان',
#  125: 'أنه',
#  126: 'أحد',
#  127: 'السماوات',
#  128: 'منهم',
#  129: 'إليه',
#  130: 'لأني',
#  131: 'سنة',
#  132: 'مثل',
#  133: 'بما',
#  134: 'لها',
#  135: 'فإن',
#  136: 'قبل',
#  137: 'لنا',
#  138: 'الأمم',
#  139: 'البيت',
#  140: 'الكاهن',
#  141: 'منه',
#  142: 'الآن',
#  143: 'كانت',
#  144: 'لما',
#  145: 'جدا',
#  146: 'جاء',
#  147: 'هوذا',
#  148: 'كنت',
#  149: 'هؤلاء',
#  150: 'هل',
#  151: 'شاول',
#  152: 'تكون',
#  153: 'عليك',
#  154: 'لذلك',
#  155: 'فلم',
#  156: 'البحر',
#  157: 'حين',
#  158: 'يعقوب',
#  159: 'الرجل',
#  160: 'إني',
#  161: 'إنه',
#  162: 'تحت',
#  163: 'نفسه',
#  164: 'كثيرة',
#  165: 'نحن',
#  166: 'يد',
#  167: 'إلهك',
#  168: 'قل',
#  169: 'عليها',
#  170: 'قالوا',
#  171: 'يكن',
#  172: 'غير',
#  173: 'عليكم',
#  174: 'إلي',
#  175: 'السيد',
#  176: 'الحق',
#  177: 'الشر',
#  178: 'كلام',
#  179: 'إنسان',
#  180: 'لأنهم',
#  181: 'أمر',
#  182: 'تلك',
#  183: 'الكهنة',
#  184: 'بابل',
#  185: 'وقد',
#  186: 'لأجل',
#  187: 'أم',
#  188: 'عمل',
#  189: 'نحو',
#  190: 'وهم',
#  191: 'وسط',
#  192: 'اليهود',
#  193: 'الأبد',
#  194: 'شيئا',
#  195: 'عنه',
#  196: 'إليك',
#  197: 'فرعون',
#  198: 'والذين',
#  199: 'عظيم',
#  200: 'وأنا',
#  201: 'الجنود',
#  202: 'حينئذ',
#  203: 'وجميع',
#  204: 'لئلا',
#  205: 'الثاني',
#  206: 'النار',
#  207: 'ذهب',
#  208: 'امرأة',
#  209: 'سليمان',
#  210: 'علي',
#  211: 'الكلام',
#  212: 'جبل',
#  213: 'الأيام',
#  214: 'أني',
#  215: 'كنتم',
#  216: 'قائلين',
#  217: 'آمنوا',
#  218: 'عشرة',
#  219: 'خير',
#  220: 'إبراهيم',
#  221: 'لماذا',
#  222: 'مدينة',
#  223: 'رجال',
#  224: 'كذلك',
#  225: 'السنة',
#  226: 'منها',
#  227: 'كيف',
#  228: 'رئيس',
#  229: 'والله',
#  230: 'ماذا',
#  231: 'الثالث',
#  232: 'وجه',
#  233: 'ابنه',
#  234: 'نفسي',
#  235: 'ويكون',
#  236: 'لله',
#  237: 'واحدة',
#  238: 'رؤساء',
#  239: 'بكل',
#  240: 'لكن',
#  241: 'الموت',
#  242: 'عيني',
#  243: 'يده',
#  244: 'ولد',
#  245: 'لأنك',
#  246: 'يأتي',
#  247: 'وإلى',
#  248: 'اسمه',
#  249: 'يوسف',
#  250: 'طريق',
#  251: 'إنما',
#  252: 'باب',
#  253: 'البرية',
#  254: 'المذبح',
#  255: 'الروح',
#  256: 'والأرض',
#  257: 'فأجاب',
#  258: 'سمع',
#  259: 'فمن',
#  260: 'هارون',
#  261: 'منكم',
#  262: 'الجميع',
#  263: 'حيث',
#  264: 'يعلم',
#  265: 'وليس',
#  266: 'وقالوا',
#  267: 'أقول',
#  268: 'فوق',
#  269: 'ماء',
#  270: 'أكثر',
#  271: 'ثلاثة',
#  272: 'أبي',
#  273: 'مما',
#  274: 'الطريق',
#  275: 'الأمر',
#  276: 'ربك',
#  277: 'صوت',
#  278: 'الأول',
#  279: 'تكلم',
#  280: 'قدام',
#  281: 'علينا',
#  282: 'كلمة',
#  283: 'الكتاب',
#  284: 'واحدا',
#  285: 'يدي',
#  286: 'الشهر',
#  287: 'الرابع',
#  288: 'هأنذا',
#  289: 'الشعوب',
#  290: 'سيدي',
#  291: 'وراء',
#  292: 'سبعة',
#  293: 'السابع',
#  294: 'بيته',
#  295: 'رأى',
#  296: 'سبط',
#  297: 'يشوع',
#  298: 'بلا',
#  299: 'منذ',
#  300: 'آخر',
#  301: 'الرجال',
#  302: 'شعب',
#  303: 'كثيرا',
#  304: 'لكل',
#  305: 'العالم',
#  306: 'وكانت',
#  307: 'بهم',
#  308: 'الحياة',
#  309: 'معك',
#  310: 'إليكم',
#  311: 'متى',
#  312: 'قوم',
#  313: 'النبي',
#  314: 'والعشرون',
#  315: 'القدس',
#  316: 'الشمس',
#  317: 'شعبي',
#  318: 'فكان',
#  319: 'إلهنا',
#  320: 'فضة',
#  321: 'ها',
#  322: 'فقد',
#  323: 'كفروا',
#  324: 'وأنت',
#  325: 'الحقل',
#  326: 'معي',
#  327: 'هنا',
#  328: 'جهة',
#  329: 'والآن',
#  330: 'الجبال',
#  331: 'أولئك',
#  332: 'الباب',
#  333: 'الخامس',
#  334: 'يدك',
#  335: 'بي',
#  336: 'قلبه',
#  337: 'عظيمة',
#  338: 'آدم',
#  339: 'فهو',
#  340: 'بالله',
#  341: 'إلهكم',
#  342: 'ربنا',
#  343: 'الليل',
#  344: 'روح',
#  345: 'خيمة',
#  346: 'الأردن',
#  347: 'أين',
#  348: 'ذبيحة',
#  349: 'الجبل',
#  350: 'اسم',
#  351: 'الفلسطينيين',
#  352: 'ثلاث',
#  353: 'أهل',
#  354: 'لمن',
#  355: 'كلها',
#  356: 'صهيون',
#  357: 'سفر',
#  358: 'فإذا',
#  359: 'أرسل',
#  360: 'العظيم',
#  361: 'صار',
#  362: 'مدن',
#  363: 'ألف',
#  364: 'رجلا',
#  365: 'المرأة',
#  366: 'نفسك',
#  367: 'فإنه',
#  368: 'وإذ',
#  369: 'الحكمة',
#  370: 'يخرج',
#  371: 'المياه',
#  372: 'أنفسهم',
#  373: 'اسرائيل',
#  374: 'بهذا',
#  375: 'موآب',
#  376: 'وأخذ',
#  377: 'قلت',
#  378: 'سكان',
#  379: 'كله',
#  380: 'سبع',
#  381: 'خرج',
#  382: 'جميعا',
#  383: 'الفضة',
#  384: 'الهيكل',
#  385: 'ألفا',
#  386: 'رأس',
#  387: 'نعمة',
#  388: 'أفرايم',
#  389: 'الحرب',
#  390: 'لو',
#  391: 'قلبك',
#  392: 'الرحمن',
#  393: 'وعمل',
#  394: 'الذهب',
#  395: 'بك',
#  396: 'عذاب',
#  397: 'إنا',
#  398: 'قلوبهم',
#  399: 'جعل',
#  400: 'خارج',
#  401: 'الرحيم',
#  402: 'نفس',
#  403: 'فما',
#  404: 'لبني',
#  405: 'قلب',
#  406: 'للذين',
#  407: 'لداود',
#  408: 'عبدك',
#  409: 'بنت',
#  410: 'المزمور',
#  411: 'ابني',
#  412: 'بولس',
#  413: 'الاجتماع',
#  414: 'يسمع',
#  415: 'فقالت',
#  416: 'إليهم',
#  417: 'معهم',
#  418: 'وجهه',
#  419: 'ولو',
#  420: 'عنهم',
#  421: 'السيف',
#  422: 'السادس',
#  423: 'وملك',
#  424: 'نار',
#  425: 'عبر',
#  426: 'فعل',
#  427: 'ألا',
#  428: 'كثير',
#  429: 'عظيما',
#  430: 'وأن',
#  431: 'وأنتم',
#  432: 'أنهم',
#  433: 'وبنو',
#  434: 'الواحد',
#  435: 'الموضع',
#  436: 'الماء',
#  437: 'معكم',
#  438: 'أشور',
#  439: 'وبعد',
#  440: 'خطية',
#  441: 'أنك',
#  442: 'صنع',
#  443: 'وهي',
#  444: 'البر',
#  445: 'معا',
#  446: 'قلبي',
#  447: 'بعض',
#  448: 'أبيه',
#  449: 'الإخوة',
#  450: 'بالحق',
#  451: 'مجد',
#  452: 'ملوك',
#  453: 'كنا',
#  454: 'المدن',
#  455: 'غضب',
#  456: 'الثامن',
#  457: 'يشاء',
#  458: 'إلهي',
#  459: 'بينهم',
#  460: 'الارض',
#  461: 'يفعل',
#  462: 'لأنكم',
#  463: 'الشمال',
#  464: 'الأشرار',
#  465: 'فان',
#  466: 'مكان',
#  467: 'دخل',
#  468: 'وجاء',
#  469: 'الجماعة',
#  470: 'كثيرين',
#  471: 'جلعاد',
#  472: 'أمة',
#  473: 'تكن',
#  474: 'سنين',
#  475: 'عني',
#  476: 'آلهة',
#  477: 'الناموس',
#  478: 'بطرس',
#  479: 'النساء',
#  480: 'قوة',
#  481: 'إرميا',
#  482: 'ابنا',
#  483: 'الشرير',
#  484: 'منسى',
#  485: 'بنيامين',
#  486: 'وجعل',
#  487: 'وقت',
#  488: 'يأكل',
#  489: 'علم',
#  490: 'ولقد',
#  491: 'شعبه',
#  492: 'لان',
#  493: 'ملكا',
#  494: 'حي',
#  495: 'الدهر',
#  496: 'سمعت',
#  497: 'سمعان',
#  498: 'الآب',
#  499: 'الجسد',
#  500: 'ألم',
#  501: 'بالسيف',
#  502: 'والذي',
#  503: 'تابوت',
#  504: 'فخرج',
#  505: 'عنده',
#  506: 'يعمل',
#  507: 'رأيت',
#  508: 'وكلم',
#  509: 'يوآب',
#  510: 'دم',
#  511: 'فإني',
#  512: 'السامرة',
#  513: 'يقولون',
#  514: 'الوقت',
#  515: 'بحسب',
#  516: 'يدخل',
#  517: 'لست',
#  518: 'مات',
#  519: 'آلاف',
#  520: 'فقالوا',
#  521: 'يوحنا',
#  522: 'سورة',
#  523: 'دون',
#  524: 'يوجد',
#  525: 'للملك',
#  526: 'لن',
#  527: 'سبيل',
#  528: 'ذكر',
#  529: 'أخرى',
#  530: 'بالنار',
#  531: 'صموئيل',
#  532: 'بيد',
#  533: 'قليلا',
#  534: 'لأنها',
#  535: 'الدنيا',
#  536: 'المحلة',
#  537: 'وكانوا',
#  538: 'جانب',
#  539: 'أولا',
#  540: 'لأننا',
#  541: 'ويل',
#  542: 'أعلم',
#  543: 'أي',
#  544: 'النهر',
#  545: 'أليس',
#  546: 'القلب',
#  547: 'الأنبياء',
#  548: 'أخذ',
#  549: 'المكان',
#  550: 'خبزا',
#  551: 'أرام',
#  552: 'رأسه',
#  553: 'وادي',
#  554: 'يعلمون',
#  555: 'تعلمون',
#  556: 'فالآن',
#  557: 'وقل',
#  558: 'إليها',
#  559: 'اذ',
#  560: 'باسم',
#  561: 'الشيطان',
#  562: 'وهذه',
#  563: 'بسم',
#  564: 'سلام',
#  565: 'إنك',
#  566: 'التاسع',
#  567: 'فأخذ',
#  568: 'خمس',
#  569: 'عينيك',
#  570: 'أربعة',
#  571: 'يموت',
#  572: 'ربهم',
#  573: 'العلي',
#  574: 'عبيده',
#  575: 'اللاويين',
#  576: 'يتكلم',
#  577: 'فأرسل',
#  578: 'أدوم',
#  579: 'الامم',
#  580: 'تقول',
#  581: 'الإصحاح',
#  582: 'شر',
#  583: 'شعبك',
#  584: 'اذهب',
#  585: 'حزقيا',
#  586: 'سيد',
#  587: 'عمون',
#  588: 'كثيرون',
#  589: 'النهار',
#  590: 'أربع',
#  591: 'حق',
#  592: 'حياة',
#  593: 'عليم',
#  594: 'خلق',
#  595: 'السبت',
#  596: 'الإيمان',
#  597: 'فيكون',
#  598: 'اذا',
#  599: 'وذهب',
#  600: 'أيديهم',
#  601: 'المساء',
#  602: 'المقدس',
#  603: 'خيرا',
#  604: 'لنفسك',
#  605: 'يوما',
#  606: 'فجاء',
#  607: 'الخطية',
#  608: 'أمه',
#  609: 'صارت',
#  610: 'آبائهم',
#  611: 'وتكون',
#  612: 'لنفسه',
#  613: 'الساعة',
#  614: 'اما',
#  615: 'كلم',
#  616: 'الدم',
#  617: 'المئة',
#  618: 'جيش',
#  619: 'الجنوب',
#  620: 'المؤمنين',
#  621: 'عنها',
#  622: 'منك',
#  623: 'الملوك',
#  624: 'الحادي',
#  625: 'عبيد',
#  626: 'وأرسل',
#  627: 'فقط',
#  628: 'وهذا',
#  629: 'أنزل',
#  630: 'ملاك',
#  631: 'جماعة',
#  632: 'بسبب',
#  633: 'يصنع',
#  634: 'اورشليم',
#  635: 'قام',
#  636: 'الآخر',
#  637: 'الصباح',
#  638: 'ربكم',
#  639: 'ملكوت',
#  640: 'أمامك',
#  641: 'عينيه',
#  642: 'والثلاثون',
#  643: 'وجد',
#  644: 'تعملون',
#  645: 'عوضا',
#  646: 'إسحاق',
#  647: 'تلاميذه',
#  648: 'فقام',
#  649: 'يقدر',
#  650: 'وعشرين',
#  651: 'فعلت',
#  652: 'يؤمنون',
#  653: 'وفيما',
#  654: 'الشريعة',
#  655: 'ايها',
#  656: 'اليه',
#  657: 'اسمك',
#  658: 'يقتل',
#  659: 'إنهم',
#  660: 'مكانه',
#  661: 'بكم',
#  662: 'ينبغي',
#  663: 'لحم',
#  664: 'الإثم',
#  665: 'وخرج',
#  666: 'خمسة',
#  667: 'الأمور',
#  668: 'انه',
#  669: 'الغنم',
#  670: 'والرب',
#  671: 'رحمة',
#  672: 'اسمعوا',
#  673: 'ربي',
#  674: 'منا',
#  675: 'الدار',
#  676: 'يديه',
#  677: 'ليست',
#  678: 'بعضهم',
#  679: 'يحب',
#  680: 'جاءوا',
#  681: 'رؤوس',
#  682: 'وبيت',
#  683: 'العذاب',
#  684: 'امام',
#  685: 'الصديق',
#  686: 'بنات',
#  687: 'وهارون',
#  688: 'كلهم',
#  689: 'يعرف',
#  690: 'تأتي',
#  691: 'الإله',
#  692: 'شريعة',
#  693: 'وعن',
#  694: 'ذراعا',
#  695: 'ست',
#  696: 'وحده',
#  697: 'أنكم',
#  698: 'رحمته',
#  699: 'عندما',
#  700: 'عين',
#  701: 'ومات',
#  702: 'عشيرة',
#  703: 'لهما',
#  704: 'كنعان',
#  705: 'أبشالوم',
#  706: 'لجميع',
#  707: 'القوم',
#  708: 'أمامه',
#  709: 'عيسو',
#  710: 'خبز',
#  711: 'تكلمت',
#  712: 'بيتك',
#  713: 'تعلم',
#  714: 'مياه',
#  715: 'أتى',
#  716: 'المسكن',
#  717: 'حكمة',
#  718: 'عبد',
#  719: 'أنفسكم',
#  720: 'او',
#  721: 'عهد',
#  722: 'بغير',
#  723: 'وجهك',
#  724: 'يوناتان',
#  725: 'الحكيم',
#  726: 'داخل',
#  727: 'المحرقة',
#  728: 'فهم',
#  729: 'الخير',
#  730: 'الصلاة',
#  731: 'آية',
#  732: 'بعضا',
#  733: 'بصوت',
#  734: 'وعشرون',
#  735: 'يربعام',
#  736: 'وقالت',
#  737: 'الكل',
#  738: 'ونحن',
#  739: 'ليلا',
#  740: 'يوناثان',
#  741: 'قول',
#  742: 'عندك',
#  743: 'أمامي',
#  744: 'محرقة',
#  745: 'فيك',
#  746: 'نزل',
#  747: 'فيما',
#  748: 'معنا',
#  749: 'نوح',
#  750: 'فقلت',
#  751: 'بينكم',
#  752: 'إيليا',
#  753: 'العهد',
#  754: 'الجيش',
#  755: 'أصحاب',
#  756: 'فيكم',
#  757: 'تخرج',
#  758: 'فم',
#  759: 'يرى',
#  760: 'شرا',
#  761: 'بقية',
#  762: 'وضرب',
#  763: 'النفس',
#  764: 'نصيب',
#  765: 'عنك',
#  766: 'قلوبكم',
#  767: 'نحاس',
#  768: 'الأولى',
#  769: 'جهنم',
#  770: 'حسن',
#  771: 'وكذلك',
#  772: 'أذرع',
#  773: 'الأموات',
#  774: 'امرأته',
#  775: 'مبين',
#  776: 'جسد',
#  777: 'ابنة',
#  778: 'ههنا',
#  779: 'امر',
#  780: 'مرة',
#  781: 'شيوخ',
#  782: 'الحي',
#  783: 'لدى',
#  784: 'فانه',
#  785: 'الكلمة',
#  786: 'مريم',
#  787: 'القيامة',
#  788: 'يعملون',
#  789: 'دائما',
#  790: 'لبيت',
#  791: 'أول',
#  792: 'وهكذا',
#  793: 'النور',
#  794: 'صاحبه',
#  795: 'إخوته',
#  796: 'لقد',
#  797: 'ودعا',
#  798: 'تقدمة',
#  799: 'عدد',
#  800: 'واسم',
#  801: 'فكيف',
#  802: 'انا',
#  803: 'بيوت',
#  804: 'بالرب',
#  805: 'لهذا',
#  806: 'وصعد',
#  807: 'ثيابه',
#  808: 'أيتها',
#  809: 'عشائرهم',
#  810: 'نارا',
#  811: 'شاء',
#  812: 'أكون',
#  813: 'قليل',
#  814: 'وعند',
#  815: 'مكتوب',
#  816: 'ليد',
#  817: 'إثم',
#  818: 'الخمر',
#  819: 'لموسى',
#  820: 'الريح',
#  821: 'قالت',
#  822: 'ذراع',
#  823: 'فتكون',
#  824: 'ونزلوا',
#  825: 'الغد',
#  826: 'كتاب',
#  827: 'أفعل',
#  828: 'يطلب',
#  829: 'الجمع',
#  830: 'سلطان',
#  831: 'عمله',
#  832: 'إياها',
#  833: 'عبيدك',
#  834: 'صعد',
#  835: 'اليهودية',
#  836: 'تخم',
#  837: 'فدعا',
#  838: 'عنكم',
#  839: 'فيهم',
#  840: 'ارض',
#  841: 'إيل',
#  842: 'يقوم',
#  843: 'عهدا',
#  844: 'الدهور',
#  845: 'موضع',
#  846: 'أخآب',
#  847: 'برية',
#  848: 'السجن',
#  849: 'شجرة',
#  850: 'للناس',
#  851: 'العظيمة',
#  852: 'السلام',
#  853: 'طوبيا',
#  854: 'قرية',
#  855: 'الرسول',
#  856: 'الملائكة',
#  857: 'الجليل',
#  858: 'انظر',
#  859: 'مني',
#  860: 'صور',
#  861: 'مذبح',
#  862: 'وعد',
#  863: 'وعملوا',
#  864: 'سمعوا',
#  865: 'القديسين',
#  866: 'بيده',
#  867: 'بكر',
#  868: 'انت',
#  869: 'قيل',
#  870: 'عشرين',
#  871: 'سلاه',
#  872: 'أعظم',
#  873: 'صنعت',
#  874: 'قتل',
#  875: 'بعيد',
#  876: 'آيات',
#  877: 'طوبى',
#  878: 'الهاوية',
#  879: 'بجميع',
#  880: 'ربه',
#  881: 'اسمي',
#  882: 'وأتى',
#  883: 'رجع',
#  884: 'الأنهار',
#  885: 'أربعين',
#  886: 'بنيه',
#  887: 'مبارك',
#  888: 'حسنا',
#  889: 'آبائه',
#  890: 'أحدا',
#  891: 'يرجع',
#  892: 'آمين',
#  893: 'ترى',
#  894: 'أمور',
#  895: 'قدامه',
#  896: 'العدو',
#  897: 'للشعب',
#  898: 'الظالمين',
#  899: 'تسمع',
#  900: 'تأكل',
#  901: 'العمل',
#  902: 'الرسل',
#  903: 'بشر',
#  904: 'بأن',
#  905: 'بعضكم',
#  906: 'وجهي',
#  907: 'أبيك',
#  908: 'يسمعوا',
#  909: 'اثنين',
#  910: 'يقال',
#  911: 'القتال',
#  912: 'نور',
#  913: 'غضبه',
#  914: 'رحيم',
#  915: 'حكيم',
#  916: 'جعلت',
#  917: 'الآخرة',
#  918: 'لاوي',
#  919: 'المغنين',
#  920: 'سريعا',
#  921: 'صالح',
#  922: 'رأوبين',
#  923: 'ايام',
#  924: 'الرؤساء',
#  925: 'قم',
#  926: 'دانيآل',
#  927: 'العزيز',
#  928: 'نصف',
#  929: 'الدين',
#  930: 'رسول',
#  931: 'حجارة',
#  932: 'مقابل',
#  933: 'تخف',
#  934: 'يريد',
#  935: 'الانسان',
#  936: 'يجعل',
#  937: 'للحرب',
#  938: 'لانه',
#  939: 'كن',
#  940: 'وبقية',
#  941: 'الملاك',
#  942: 'خذ',
#  943: 'حول',
#  944: 'أبواب',
#  945: 'إياه',
#  946: 'الشرق',
#  947: 'شديد',
#  948: 'العاشر',
#  949: 'ورؤساء',
#  950: 'وأيضا',
#  951: 'مرات',
#  952: 'يذهب',
#  953: 'قريب',
#  954: 'ستة',
#  955: 'القدير',
#  956: 'إنها',
#  957: 'جاد',
#  958: 'كرسي',
#  959: 'عندي',
#  960: 'ملكه',
#  961: 'وإخوته',
#  962: 'فماذا',
#  963: 'أخيه',
#  964: 'فدخل',
#  965: 'قدس',
#  966: 'جنات',
#  967: 'الخبز',
#  968: 'كلا',
#  969: 'ورسوله',
#  970: 'الكلدانيين',
#  971: 'رسلا',
#  972: 'الزمان',
#  973: 'المجد',
#  974: 'تجري',
#  975: 'أسباط',
#  976: 'يسمعون',
#  977: 'عما',
#  978: 'فارس',
#  979: 'دان',
#  980: 'جئت',
#  981: 'كلامي',
#  982: 'الجنة',
#  983: 'والأربعون',
#  984: 'الثلاثة',
#  985: 'خرجت',
#  986: 'ذي',
#  987: 'بسلام',
#  988: 'بغتة',
#  989: 'وصنع',
#  990: 'إلها',
#  991: 'نجسا',
#  992: 'حبرون',
#  993: 'تكونوا',
#  994: 'حقا',
#  995: 'أرسلني',
#  996: 'يأخذ',
#  997: 'وخمسة',
#  998: 'فذهب',
#  999: 'إلينا',
#  ...}

# %% [markdown]
# # Subsampling by Mikolov

# %%
threshold = 1e-3
word_counts = Counter(int_words)
total_count = len(int_words)
print(word_counts, total_count)
# Out:
# Counter({0: 14529, 1: 13376, 2: 6927, 3: 6527, 4: 5831, 5: 4895, 6: 4608, 7: 4367, 8: 3625, 9: 3487, 10: 2991, 11: 2887, 12: 2723, 13: 2520, 14: 2369, 15: 2203, 16: 2082, 17: 2076, 18: 2025, 19: 2013, 20: 2012, 21: 1974, 22: 1962, 23: 1948, 24: 1721, 25: 1662, 26: 1589, 27: 1578, 28: 1569, 29: 1558, 30: 1462, 31: 1458, 32: 1406, 33: 1341, 34: 1335, 35: 1330, 36: 1324, 37: 1285, 38: 1281, 39: 1262, 40: 1220, 41: 1180, 42: 1160, 43: 1147, 44: 1138, 45: 1137, 46: 1132, 47: 1119, 48: 1114, 49: 1069, 50: 1051, 51: 1050, 52: 1035, 53: 1027, 54: 1026, 55: 1009, 56: 1003, 57: 993, 58: 970, 59: 969, 60: 957, 61: 953, 62: 911, 63: 908, 64: 904, 65: 870, 66: 857, 67: 857, 68: 852, 69: 825, 70: 804, 71: 802, 72: 791, 73: 785, 74: 784, 75: 783, 76: 782, 77: 774, 78: 774, 79: 766, 80: 760, 81: 760, 82: 755, 83: 747, 84: 746, 85: 725, 86: 707, 87: 707, 88: 694, 89: 694, 90: 691, 91: 688, 92: 687, 93: 685, 94: 677, 95: 672, 96: 670, 97: 662, 98: 637, 99: 636, 100: 630, 101: 625, 102: 620, 103: 614, 104: 609, 105: 601, 106: 583, 107: 582, 108: 571, 109: 570, 110: 567, 111: 546, 112: 544, 113: 537, 114: 533, 115: 530, 116: 521, 117: 512, 118: 510, 119: 506, 120: 505, 121: 496, 122: 481, 123: 474, 124: 473, 125: 470, 126: 454, 127: 450, 128: 449, 129: 448, 130: 448, 131: 445, 132: 442, 133: 437, 134: 427, 135: 427, 136: 424, 137: 419, 138: 417, 139: 407, 140: 406, 141: 404, 142: 403, 143: 401, 144: 400, 145: 397, 146: 396, 147: 394, 148: 387, 149: 387, 150: 385, 151: 384, 152: 378, 153: 376, 154: 374, 155: 374, 156: 372, 157: 370, 158: 370, 159: 369, 160: 365, 161: 360, 162: 359, 163: 356, 164: 355, 165: 354, 166: 353, 167: 353, 168: 350, 169: 349, 170: 349, 171: 347, 172: 343, 173: 339, 174: 339, 175: 338, 176: 333, 177: 332, 178: 331, 179: 330, 180: 329, 181: 327, 182: 327, 183: 324, 184: 323, 185: 323, 186: 318, 187: 316, 188: 314, 189: 314, 190: 312, 191: 312, 192: 310, 193: 310, 194: 309, 195: 308, 196: 306, 197: 302, 198: 301, 199: 300, 200: 297, 201: 297, 202: 293, 203: 292, 204: 290, 205: 290, 206: 287, 207: 287, 208: 286, 209: 284, 210: 284, 211: 283, 212: 283, 213: 282, 214: 281, 215: 281, 216: 280, 217: 280, 218: 276, 219: 274, 220: 274, 221: 273, 222: 271, 223: 271, 224: 271, 225: 268, 226: 268, 227: 267, 228: 267, 229: 266, 230: 265, 231: 262, 232: 262, 233: 260, 234: 259, 235: 258, 236: 257, 237: 257, 238: 254, 239: 254, 240: 251, 241: 251, 242: 250, 243: 250, 244: 250, 245: 248, 246: 246, 247: 244, 248: 243, 249: 243, 250: 241, 251: 241, 252: 241, 253: 240, 254: 240, 255: 238, 256: 237, 257: 235, 258: 235, 259: 234, 260: 233, 261: 232, 262: 228, 263: 228, 264: 227, 265: 226, 266: 226, 267: 226, 268: 225, 269: 224, 270: 224, 271: 224, 272: 223, 273: 222, 274: 222, 275: 222, 276: 220, 277: 219, 278: 219, 279: 218, 280: 215, 281: 215, 282: 213, 283: 212, 284: 211, 285: 210, 286: 210, 287: 210, 288: 210, 289: 209, 290: 208, 291: 208, 292: 208, 293: 207, 294: 206, 295: 206, 296: 206, 297: 206, 298: 205, 299: 205, 300: 204, 301: 204, 302: 203, 303: 203, 304: 203, 305: 203, 306: 202, 307: 202, 308: 202, 309: 201, 310: 199, 311: 199, 312: 199, 313: 197, 314: 196, 315: 195, 316: 195, 317: 195, 318: 193, 319: 191, 320: 191, 321: 191, 322: 190, 323: 189, 324: 188, 325: 188, 326: 188, 327: 187, 328: 187, 329: 186, 330: 186, 331: 185, 332: 184, 333: 183, 334: 183, 335: 181, 336: 181, 337: 181, 338: 181, 339: 178, 340: 178, 341: 178, 342: 178, 343: 177, 344: 177, 345: 177, 346: 177, 347: 176, 348: 175, 349: 175, 350: 175, 351: 175, 352: 174, 353: 174, 354: 173, 355: 172, 356: 171, 357: 171, 358: 171, 359: 171, 360: 170, 361: 168, 362: 167, 363: 167, 364: 166, 365: 166, 366: 166, 367: 166, 368: 165, 369: 165, 370: 165, 371: 165, 372: 165, 373: 164, 374: 164, 375: 163, 376: 163, 377: 162, 378: 161, 379: 161, 380: 161, 381: 160, 382: 160, 383: 159, 384: 159, 385: 159, 386: 159, 387: 159, 388: 158, 389: 158, 390: 157, 391: 157, 392: 157, 393: 157, 394: 156, 395: 156, 396: 156, 397: 156, 398: 155, 399: 155, 400: 154, 401: 154, 402: 154, 403: 154, 40 ...

# %%
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %%
len(train_words)
# Out:
# 495072

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /home/mgd-pc/.local/lib/python3.5/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-19-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %%
# %time
epochs = 40
batch_size = 1000
window_size = 3

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 6.68 µs
# Epoch 1/40 Iteration: 100 Avg. Training loss: 6.8189 0.4252 sec/batch
# Epoch 1/40 Iteration: 200 Avg. Training loss: 6.8099 0.3933 sec/batch
# Epoch 1/40 Iteration: 300 Avg. Training loss: 6.4845 0.4103 sec/batch
# Epoch 1/40 Iteration: 400 Avg. Training loss: 6.7275 0.3957 sec/batch
# Epoch 2/40 Iteration: 500 Avg. Training loss: 6.6563 0.0199 sec/batch
# Epoch 2/40 Iteration: 600 Avg. Training loss: 6.1730 0.4567 sec/batch
# Epoch 2/40 Iteration: 700 Avg. Training loss: 5.9828 0.4049 sec/batch
# Epoch 2/40 Iteration: 800 Avg. Training loss: 5.6009 0.3937 sec/batch
# Epoch 2/40 Iteration: 900 Avg. Training loss: 5.6614 0.4037 sec/batch
# Epoch 3/40 Iteration: 1000 Avg. Training loss: 5.4919 0.0376 sec/batch
# Nearest to أن: الساكنة, تدعوني, لحمنا, فطام, وانتظرونا, اخلاقا, ثدياها, الرب,
# Nearest to اليوم: وارتعبت, سفر, اسطاعوا, وقدمت, وربطوا, تقرب, فسال, ذلك,
# Nearest to إسرائيل: أسلمته, تؤمنوا, نحث, واللائي, أدركهم, وكل, الملتوي, ليمطر,
# Nearest to يقول: عقلك, إمير, وحاصروها, الليلة, بأسرع, يهبني, أجعلنا, دمه,
# Nearest to ولكن: فاخر, تيه, عدت, موتا, ثورهم, تلمسوا, الفرات, يرحمه,
# Nearest to عشر: أعوزكم, المجمرة, صنعت, أغلق, مصغ, ستدعون, شعبنا, وسط,
# Nearest to إلا: اخرجي, وكوني, خسرها, يعزونها, قلوبكم, الجوهر, فليعطها, والببغاء,
# Nearest to ومن: عثليا, العاشر, الباردة, انقرض, يدخل, السرياني, قليلة, فنحيي,
# Nearest to ضرب: كالغوغاء, خذ, نصنعه, ان, عسيئيل, ولايتهم, وصرخت, سيده,
# Nearest to شعبا: يدعونك, مبعدون, ولقائه, ورجوعه, وبقر, مطروحين, تنتزع, أبيه,
# Nearest to فكانت: ورزقكم, سرقتهم, داريوس, السقوط, الساكنين, يرجعون, لجند, شغب,
# Nearest to الفصح: فيخدمه, الجناحين, لعماسا, شفطان, الجسدي, ظن, ­وأنتم, إسماعيليين,
# Nearest to احد: عضوا, وأحصر, يحارب, ليترك, كخراف, الجبلة, السامية, فقف,
# Nearest to مكتوبة: كونتس, نجما, فاطهروا, ذريتهم, كبيرا, فاتباع, ألبس, وتتوافر,
# Nearest to هيكل: الخيمة, لبنة, وأدامة, لوح, وتتغاضى, واستخبرهما, وباركهم, قائلينآمين,
# Nearest to كتب: برجوعكم, لترزقها, دخولنا, وتكمله, وترجون, امرأتين, ولحمك, خير,
# Epoch 3/40 Iteration: 1100 Avg. Training loss: 5.1902 0.4061 sec/batch
# Epoch 3/40 Iteration: 1200 Avg. Training loss: 5.0167 0.3919 sec/batch
# Epoch 3/40 Iteration: 1300 Avg. Training loss: 4.8228 0.3936 sec/batch
# Epoch 3/40 Iteration: 1400 Avg. Training loss: 4.7833 0.4053 sec/batch
# Epoch 4/40 Iteration: 1500 Avg. Training loss: 4.6992 0.0563 sec/batch
# Epoch 4/40 Iteration: 1600 Avg. Training loss: 4.5140 0.4081 sec/batch
# Epoch 4/40 Iteration: 1700 Avg. Training loss: 4.4427 0.3983 sec/batch
# Epoch 4/40 Iteration: 1800 Avg. Training loss: 4.3217 0.3970 sec/batch
# Epoch 4/40 Iteration: 1900 Avg. Training loss: 4.3348 0.3928 sec/batch
# Epoch 5/40 Iteration: 2000 Avg. Training loss: 4.2385 0.0812 sec/batch
# Nearest to أن: الساكنة, تدعوني, فطام, لحمنا, وانتظرونا, أشراطها, بنيته, يشفوه,
# Nearest to اليوم: سفر, اسطاعوا, وارتعبت, وقدمت, فسال, رزقناكم, تحلني, يؤذن,
# Nearest to إسرائيل: تؤمنوا, نحث, أسلمته, أدركهم, الملتوي, سيعطى, أقسمت, ومتى,
# Nearest to يقول: إمير, الحسنة, دمه, ملتهبة, بأسرع, عقلك, وحاصروها, سيكون,
# Nearest to ولكن: عدت, فاخر, موتا, تيه, ثورهم, طأطأ, تلمسوا, الفرات,
# Nearest to عشر: أعوزكم, والعشرين, المجمرة, ملة, الحاضر, مصغ, لينصرف, أخزيا,
# Nearest to إلا: اخرجي, بآياتنا, خسرها, قلوبكم, وكوني, يعزونها, فليعطها, لستم,
# Nearest to ومن: عثليا, فجاءت, الصالحين, العاشر, السرياني, لينذر, انقرض, لعمل,
# Nearest to ضرب: كالغوغاء, وصرخت, عسيئيل, سيده, خذ, ولايتهم, باركوا, يلج,
# Nearest to شعبا: يدعونك, مبعدون, ورجوعه, ولقائه, ألقوا, تنتزع, ابنا, رزقناهم,
# Nearest to فكانت: ورزقكم, الساكنين, سرقتهم, يرجعون, داريوس, صنعت, يسر, السقوط,
# Nearest to الفصح: فيخدمه, ظن, لعماسا, الجناحين, تكملون, الباكورات, شفطان, الجسدي,
# Nearest to احد: عضوا, يحارب, وأحصر, كخراف, ليترك, المواعز, فقف, فيتقدس,
# Nearest to مكتوبة: كونتس, كبيرا, ذريتهم, فاطهروا, نجما, الأغبياء, ألبس, ذرة,
# Nearest to هيكل: الخيمة, لبنة, لوح, وباركهم, قريب, ابغضت, لشرب, وتتغاضى,
# Nearest to كتب: برجوعكم, دخولنا, لترزقها, الباطل, المواعيد, وترجون, خير, يطمعون,
# Epoch 5/40 Iteration: 2100 Avg. Training loss: 4.1235 0.4027 sec/batch
# Epoch 5/40 Iteration: 2200 Avg. Training loss: 4.0889 0.3912 sec/batch
# Epoch 5/40 Iteration: 2300 Avg. Training loss: 3.9763 0.4335 sec/batch
# Epoch 5/40 Iteration: 2400 Avg. Training loss: 4.0251 0.4135 sec/batch
# Epoch 6/40 Iteration: 2500 Avg. Training loss: 3.8986 0.1042 sec/batch
# Epoch 6/40 Iteration: 2600 Avg. Training loss: 3.8563 0.4359 sec/batch
# Epoch 6/40 Iteration: 2700 Avg. Training loss: 3.8043 0.4073 sec/batch
# Epoch 6/40 Iteration: 2800 Avg. Training loss: 3.7302 0.3870 sec/batch
# Epoch 6/40 Iteration: 2900 Avg. Training loss: 3.7540 0.4156 sec/batch
# Epoch 7/40 Iteration: 3000 Avg. Training loss: 3.6490 0.1382 sec/batch
# Nearest to أن: الساكنة, لحمنا, وانتظرونا, فطام, أشراطها, بنيته, يشفوه, الأعظم,
# Nearest to اليوم: وارتعبت, سفر, اسطاعوا, وقدمت, فسال, تحلني, رزقناكم, يؤذن,
# Nearest to إسرائيل: نحث, أسلمته, أدركهم, سيعطى, والمشتاق, تؤمنوا, ليمطر, الملتوي,
# Nearest to يقول: الحسنة, إمير, ملتهبة, دمه, بأسرع, أجعلنا, سيكون, وحاصروها,
# Nearest to ولكن: عدت, فاخر, طأطأ, ثورهم, شعائري, نعطيه, قبلكم, بخطايانا,
# Nearest to عشر: أعوزكم, والعشرين, المجمرة, مصغ, لينصرف, الحاضر, ترتدوا, ملة,
# Nearest to إلا: اخرجي, بآياتنا, خسرها, فليعطها, وكوني, يعزونها, وأفرح, فيفعل,
# Nearest to ومن: فجاءت, عثليا, لينذر, يدرون, الصالحين, بحسن, كورة, ويهدي,
# Nearest to ضرب: كالغوغاء, وصرخت, عسيئيل, فيحكم, ولايتهم, باصابتها, يلج, سيده,
# Nearest to شعبا: يدعونك, مبعدون, ورجوعه, ألقوا, ابنا, مطروحين, لرؤساء, لأخرجهم,
# Nearest to فكانت: ورزقكم, الساكنين, سرقتهم, صنعت, داريوس, الرابعة, لجند, لتحاكم,
# Nearest to الفصح: فيخدمه, لعماسا, ظن, للبر, الجناحين, تحذر, تكملون, انتبذت,
# Nearest to احد: عضوا, يحارب, كخراف, وأحصر, فيتقدس, المواعز, ليترك, كيس,
# Nearest to مكتوبة: كونتس, نجما, فاطهروا, الذلى, ذريتهم, ويشربوا, تفسحوا, كبيرا,
# Nearest to هيكل: الخيمة, لبنة, لوح, كصدع, والمشايخ, ابغضت, وتتغاضى, وباركهم,
# Nearest to كتب: برجوعكم, دخولنا, المواعيد, يطمعون, الباطل, شالح, لترزقها, تناهت,
# Epoch 7/40 Iteration: 3100 Avg. Training loss: 3.6501 0.4793 sec/batch
# Epoch 7/40 Iteration: 3200 Avg. Training loss: 3.5896 0.4236 sec/batch
# Epoch 7/40 Iteration: 3300 Avg. Training loss: 3.5116 0.4007 sec/batch
# Epoch 7/40 Iteration: 3400 Avg. Training loss: 3.5785 0.4366 sec/batch
# Epoch 8/40 Iteration: 3500 Avg. Training loss: 3.4456 0.1454 sec/batch
# Epoch 8/40 Iteration: 3600 Avg. Training loss: 3.4591 0.4241 sec/batch
# Epoch 8/40 Iteration: 3700 Avg. Training loss: 3.3949 0.4339 sec/batch
# Epoch 8/40 Iteration: 3800 Avg. Training loss: 3.3227 0.4308 sec/batch
# Epoch 8/40 Iteration: 3900 Avg. Training loss: 3.4322 0.4351 sec/batch
# Epoch 9/40 Iteration: 4000 Avg. Training loss: 3.2611 0.1735 sec/batch
# Nearest to أن: الساكنة, أشراطها, وانتظرونا, لحمنا, يشفوه, الأعظم, فطام, بنيته,
# Nearest to اليوم: وارتعبت, اسطاعوا, سفر, تحلني, وقدمت, خاصتهم, والفأر, فسال,
# Nearest to إسرائيل: نحث, أسلمته, والمشتاق, أدركهم, سيعطى, ليمطر, واصطنعتك, أبذلك,
# Nearest to يقول: الحسنة, ملتهبة, بأسرع, إمير, دمه, أجعلنا, عقلك, وحاصروها,
# Nearest to ولكن: طأطأ, عدت, شعائري, نعطيه, ثورهم, قبلكم, فاخر, بكرك,
# Nearest to عشر: أعوزكم, والعشرين, وعشر, المجمرة, والثلاثون, مصغ, تترنم, لينصرف,
# Nearest to إلا: اخرجي, خسرها, فليعطها, بآياتنا, وأفرح, وكوني, شركاءكم, والمحروم,
# Nearest to ومن: فجاءت, الصادق, لينذر, عثليا, بحسن, يدرون, كورة, ويهدي,
# Nearest to ضرب: عسيئيل, كالغوغاء, وصرخت, باصابتها, فيحكم, لناحور, ولايتهم, ليحلف,
# Nearest to شعبا: يدعونك, مبعدون, مطروحين, ورجوعه, لأخرجهم, لرؤساء, ابنا, فتولد,
# Nearest to فكانت: ورزقكم, الساكنين, سرقتهم, لجند, الرابعة, داريوس, صنعت, لتحاكم,
# Nearest to الفصح: لعماسا, فيخدمه, للبر, ظن, انتبذت, الباكورات, الجناحين, صخور,
# Nearest to احد: عضوا, فيتقدس, يحارب, المواعز, وأحصر, كخراف, بهيج, جبهتك,
# Nearest to مكتوبة: كونتس, الذلى, فاطهروا, ويشربوا, نجما, الخفيات, تفسحوا, ألبس,
# Nearest to هيكل: الخيمة, لبنة, لوح, كصدع, والمشايخ, ابغضت, لشرب, يصبه,
# Nearest to كتب: دخولنا, برجوعكم, يطمعون, شالح, المواعيد, يعلل, لترزقها, حمة,
# Epoch 9/40 Iteration: 4100 Avg. Training loss: 3.3168 0.4372 sec/batch
# Epoch 9/40 Iteration: 4200 Avg. Training loss: 3.2662 0.4441 sec/batch
# Epoch 9/40 Iteration: 4300 Avg. Training loss: 3.1193 0.4399 sec/batch
# Epoch 9/40 Iteration: 4400 Avg. Training loss: 3.2815 0.4403 sec/batch
# Epoch 10/40 Iteration: 4500 Avg. Training loss: 3.0988 0.2191 sec/batch
# Epoch 10/40 Iteration: 4600 Avg. Training loss: 3.2061 0.4416 sec/batch
# Epoch 10/40 Iteration: 4700 Avg. Training loss: 3.1203 0.4345 sec/batch
# Epoch 10/40 Iteration: 4800 Avg. Training loss: 3.0042 0.4399 sec/batch
# Epoch 10/40 Iteration: 4900 Avg. Training loss: 3.1709 0.4489 sec/batch
# Epoch 11/40 Iteration: 5000 Avg. Training loss: 2.9698 0.2207 sec/batch
# Nearest to أن: أشراطها, وانتظرونا, لحمنا, الأعظم, يشفوه, فطام, الساكنة, بنيته,
# Nearest to اليوم: وارتعبت, اسطاعوا, سفر, تحلني, وقدمت, خاصتهم, وحجارته, والفأر,
# Nearest to إسرائيل: نحث, والمشتاق, أبذلك, ليمطر, أدركهم, واصطنعتك, أسلمته, سيعطى,
# Nearest to يقول: الحسنة, عقلك, ولبنيامين, ملتهبة, بأسرع, إمير, وحاصروها, أجعلنا,
# Nearest to ولكن: طأطأ, ثورهم, نعطيه, عدت, ومنافع, بكرك, شعائري, أداه,
# Nearest to عشر: والعشرين, أعوزكم, وعشر, والثلاثون, المجمرة, لينصرف, مصغ, السادس,
# Nearest to إلا: خسرها, فليعطها, اخرجي, والمحروم, بآياتنا, شركاءكم, وأفرح, يعزونها,
# Nearest to ومن: الصادق, فجاءت, يدرون, ونستفتحها, لينذر, ويهدي, السرياني, الشهير,
# Nearest to ضرب: عسيئيل, والمرتعد, أليعام, فيحكم, كالغوغاء, ويلك, ليحلف, سخرة,
# Nearest to شعبا: يدعونك, مبعدون, مطروحين, ورجوعه, ابنا, فتولد, لأخرجهم, لرؤساء,
# Nearest to فكانت: ورزقكم, الساكنين, لجند, الرابعة, داريوس, سرقتهم, كار, لتحاكم,
# Nearest to الفصح: فيخدمه, لعماسا, للبر, انتبذت, ظن, صخور, طابت, الباكورات,
# Nearest to احد: عضوا, فيتقدس, المواعز, يحارب, جبهتك, وأحصر, يفاوضوكم, بهيج,
# Nearest to مكتوبة: كونتس, الذلى, التثبيت, تفسحوا, الخفيات, فاطهروا, ويشربوا, بحبر,
# Nearest to هيكل: الخيمة, كصدع, لوح, والمشايخ, لبنة, وتضطجع, وانهزمت, يصبه,
# Nearest to كتب: دخولنا, شالح, برجوعكم, يطمعون, يعلل, سأتلو, رهبة, المواعيد,
# Epoch 11/40 Iteration: 5100 Avg. Training loss: 3.0948 0.4544 sec/batch
# Epoch 11/40 Iteration: 5200 Avg. Training loss: 2.9852 0.4414 sec/batch
# Epoch 11/40 Iteration: 5300 Avg. Training loss: 2.8837 0.4441 sec/batch
# Epoch 11/40 Iteration: 5400 Avg. Training loss: 3.0595 0.4427 sec/batch
# Epoch 12/40 Iteration: 5500 Avg. Training loss: 2.8464 0.2456 sec/batch
# Epoch 12/40 Iteration: 5600 Avg. Training loss: 3.0146 0.4641 sec/batch
# Epoch 12/40 Iteration: 5700 Avg. Training loss: 2.8709 0.4233 sec/batch
# Epoch 12/40 Iteration: 5800 Avg. Training loss: 2.7529 0.4307 sec/batch
# Epoch 12/40 Iteration: 5900 Avg. Training loss: 2.9872 0.4297 sec/batch
# Epoch 13/40 Iteration: 6000 Avg. Training loss: 2.7439 0.2584 sec/batch
# Nearest to أن: وانتظرونا, أشراطها, لحمنا, يشفوه, الأعظم, فطام, رشيد, بنيته,
# Nearest to اليوم: وارتعبت, تحلني, خاصتهم, سفر, اسطاعوا, وحجارته, وقدمت, والفأر,
# Nearest to إسرائيل: نحث, والمشتاق, أبذلك, وأشتأول, ليمطر, للتسعة, أدركهم, للشبكتين,
# Nearest to يقول: ولبنيامين, الحسنة, بأسرع, إمير, ملتهبة, سيكون, ارتأيت, تمتلكونها,
# Nearest to ولكن: ثورهم, طأطأ, ومنافع, نعطيه, عدت, بكرك, شعائري, غاوين,
# Nearest to عشر: والعشرين, أعوزكم, وعشر, لينصرف, والثلاثون, المجمرة, قائلالو, عشار,
# Nearest to إلا: فليعطها, خسرها, اخرجي, والمحروم, شركاءكم, الفوز, منقلبا, سألتهم,
# Nearest to ومن: الصادق, لينذر, فجاءت, ونستفتحها, ويهدي, وتقلده, السرياني, يدرون,
# Nearest to ضرب: عسيئيل, والمرتعد, أليعام, سخرة, لناحور, فيحكم, كالغوغاء, ويلك,
# Nearest to شعبا: يدعونك, مطروحين, مبعدون, فليقاتل, ورجوعه, تكهن, تمييزا, فتولد,
# Nearest to فكانت: لجند, ورزقكم, الساكنين, الرابعة, داريوس, كار, لتحاكم, سرقتهم,
# Nearest to الفصح: فيخدمه, لعماسا, ومشيريك, للبر, الباكورات, والمغنون, انتبذت, طابت,
# Nearest to احد: عضوا, فيتقدس, المواعز, يحارب, زمهريرا, بهيج, يفاوضوكم, وأحصر,
# Nearest to مكتوبة: كونتس, الذلى, ويشربوا, التثبيت, تفسحوا, فاطهروا, بحبر, الخفيات,
# Nearest to هيكل: الخيمة, لوح, كصدع, وتضطجع, وانهزمت, والمشايخ, لبنة, ليمجدك,
# Nearest to كتب: دخولنا, شالح, سأتلو, يطمعون, يعلل, برجوعكم, رهبة, توكلنا,
# Epoch 13/40 Iteration: 6100 Avg. Training loss: 2.9297 0.4549 sec/batch
# Epoch 13/40 Iteration: 6200 Avg. Training loss: 2.7858 0.4336 sec/batch
# Epoch 13/40 Iteration: 6300 Avg. Training loss: 2.6718 0.4630 sec/batch
# Epoch 13/40 Iteration: 6400 Avg. Training loss: 2.9173 0.4308 sec/batch
# Epoch 14/40 Iteration: 6500 Avg. Training loss: 2.6428 0.2798 sec/batch
# Epoch 14/40 Iteration: 6600 Avg. Training loss: 2.8660 0.4387 sec/batch
# Epoch 14/40 Iteration: 6700 Avg. Training loss: 2.6876 0.4691 sec/batch
# Epoch 14/40 Iteration: 6800 Avg. Training loss: 2.6116 0.4221 sec/batch
# Epoch 14/40 Iteration: 6900 Avg. Training loss: 2.8312 0.4224 sec/batch
# Epoch 15/40 Iteration: 7000 Avg. Training loss: 2.5389 0.3118 sec/batch
# Nearest to أن: وانتظرونا, أشراطها, الأعظم, يشفوه, لحمنا, فيبني, رشيد, فطام,
# Nearest to اليوم: وارتعبت, خاصتهم, تحلني, وحجارته, سفر, اسطاعوا, والفأر, وقدمت,
# Nearest to إسرائيل: نحث, أبذلك, والمشتاق, واصطنعتك, وأشتأول, للشبكتين, كناموس, للتسعة,
# Nearest to يقول: ولبنيامين, الحسنة, طرقكم, استبدلوا, بأسرع, ارتأيت, فأحضرها, تمتلكونها,
# Nearest to ولكن: ومنافع, ثورهم, بكرك, طأطأ, نعطيه, عدت, ليبلو, ويحبه,
# Nearest to عشر: والعشرين, وعشر, أعوزكم, والثلاثون, قائلالو, السادس, ظهرا, للشهر,
# Nearest to إلا: فليعطها, خسرها, اخرجي, والمحروم, منقلبا, سألتهم, وينطقون, الفوز,
# Nearest to ومن: الصادق, ونستفتحها, فجاءت, ويهدي, لينذر, نصبوه, السرياني, حظياتك,
# Nearest to ضرب: عسيئيل, أليعام, سخرة, والمرتعد, ليحلف, ظفر, فيحكم, كالغوغاء,
# Nearest to شعبا: يدعونك, مطروحين, مبعدون, فليقاتل, ورجوعه, تكهن, تمييزا, تحاربها,
# Nearest to فكانت: لجند, الساكنين, الرابعة, ورزقكم, كار, داريوس, لتحاكم, معتنفا,
# Nearest to الفصح: فيخدمه, لعماسا, الباكورات, ومشيريك, عيد, الفطير, للبر, والمغنون,
# Nearest to احد: عضوا, فيتقدس, المواعز, يفاوضوكم, يحارب, حقها, وباصر, وأحصر,
# Nearest to مكتوبة: كونتس, الذلى, التثبيت, العدد, الابكار, فاطهروا, ويشربوا, بحبر,
# Nearest to هيكل: الخيمة, كصدع, لوح, وانهزمت, والمشايخ, ليمجدك, لبنة, وتضطجع,
# Nearest to كتب: دخولنا, شالح, سأتلو, يعلل, يطمعون, وايرونيمس, برجوعكم, رهبة,
# Epoch 15/40 Iteration: 7100 Avg. Training loss: 2.7991 0.4527 sec/batch
# Epoch 15/40 Iteration: 7200 Avg. Training loss: 2.6110 0.4420 sec/batch
# Epoch 15/40 Iteration: 7300 Avg. Training loss: 2.5547 0.4362 sec/batch
# Epoch 15/40 Iteration: 7400 Avg. Training loss: 2.7874 0.4217 sec/batch
# Epoch 16/40 Iteration: 7500 Avg. Training loss: 2.4877 0.3167 sec/batch
# Epoch 16/40 Iteration: 7600 Avg. Training loss: 2.7356 0.4220 sec/batch
# Epoch 16/40 Iteration: 7700 Avg. Training loss: 2.5315 0.4207 sec/batch
# Epoch 16/40 Iteration: 7800 Avg. Training loss: 2.5110 0.4282 sec/batch
# Epoch 16/40 Iteration: 7900 Avg. Training loss: 2.6966 0.4291 sec/batch
# Epoch 17/40 Iteration: 8000 Avg. Training loss: 2.4438 0.3691 sec/batch
# Nearest to أن: وانتظرونا, أشراطها, الأعظم, لحمنا, فيبني, يشفوه, رشيد, بنيته,
# Nearest to اليوم: وارتعبت, خاصتهم, تحلني, وحجارته, والفأر, سفر, اسطاعوا, تؤثر,
# Nearest to إسرائيل: نحث, أبذلك, والمشتاق, وأشتأول, واصطنعتك, للتسعة, للشبكتين, كناموس,
# Nearest to يقول: ولبنيامين, طرقكم, بأسرع, فأحضرها, استبدلوا, وشجعه, الحسنة, أتأتي,
# Nearest to ولكن: ومنافع, بكرك, كمبشر, ثورهم, طأطأ, آخرتهم, غاوين, نعطيه,
# Nearest to عشر: والعشرين, وعشر, أعوزكم, قائلالو, والثلاثون, السادس, ظهرا, للشهر,
# Nearest to إلا: فليعطها, اخرجي, خسرها, وينطقون, والمحروم, سألتهم, الفوز, منقلبا,
# Nearest to ومن: ونستفتحها, الصادق, فجاءت, ويهدي, السرياني, نصبوه, وأحباؤه, حظياتك,
# Nearest to ضرب: عسيئيل, والمرتعد, سخرة, أليعام, ظفر, ويتعد, الماكيريين, بالتنهد,
# Nearest to شعبا: يدعونك, مطروحين, مبعدون, فليقاتل, تمييزا, تكهن, ورجوعه, تحاربها,
# Nearest to فكانت: لجند, ورزقكم, الرابعة, الساكنين, داريوس, كار, معتنفا, لتحاكم,
# Nearest to الفصح: فيخدمه, عيد, الفطير, الباكورات, لعماسا, ومشيريك, والمغنون, للبر,
# Nearest to احد: عضوا, فيتقدس, المواعز, يفاوضوكم, وباصر, وأجرتها, وقرأت, يحارب,
# Nearest to مكتوبة: كونتس, التثبيت, الذلى, والأخيرة, العدد, أخبار, بحبر, وبكرو,
# Nearest to هيكل: الخيمة, كصدع, لوح, وانهزمت, ليمجدك, والمشايخ, شاشق, وتضطجع,
# Nearest to كتب: دخولنا, سأتلو, وايرونيمس, شالح, يعلل, رهبة, يطمعون, المواعيد,
# Epoch 17/40 Iteration: 8100 Avg. Training loss: 2.6513 0.4362 sec/batch
# Epoch 17/40 Iteration: 8200 Avg. Training loss: 2.4574 0.4450 sec/batch
# Epoch 17/40 Iteration: 8300 Avg. Training loss: 2.4735 0.4243 sec/batch
# Epoch 17/40 Iteration: 8400 Avg. Training loss: 2.6163 0.3933 sec/batch
# Epoch 18/40 Iteration: 8500 Avg. Training loss: 2.3922 0.3684 sec/batch
# Epoch 18/40 Iteration: 8600 Avg. Training loss: 2.5936 0.4214 sec/batch
# Epoch 18/40 Iteration: 8700 Avg. Training loss: 2.3954 0.3817 sec/batch
# Epoch 18/40 Iteration: 8800 Avg. Training loss: 2.4443 0.3814 sec/batch
# Epoch 18/40 Iteration: 8900 Avg. Training loss: 2.5751 0.4075 sec/batch
# Epoch 19/40 Iteration: 9000 Avg. Training loss: 2.3508 0.3860 sec/batch
# Nearest to أن: وانتظرونا, أشراطها, فيبني, يشفوه, سئل, الأعظم, لحمنا, رشيد,
# Nearest to اليوم: وارتعبت, خاصتهم, وحجارته, تحلني, والفأر, سفر, اسطاعوا, تؤثر,
# Nearest to إسرائيل: نحث, وأشتأول, أبذلك, والمشتاق, كناموس, للتسعة, للشبكتين, أدركهم,
# Nearest to يقول: ولبنيامين, بأسرع, طرقكم, فأحضرها, استبدلوا, وعدوكم, وشجعه, ومعيشة,
# Nearest to ولكن: بكرك, ومنافع, ليبلو, كمبشر, غاوين, ثورهم, اطرحوا, تخطه,
# Nearest to عشر: والعشرين, وعشر, قائلالو, والثلاثون, السادس, أعوزكم, الحادي, للشهر,
# Nearest to إلا: فليعطها, خسرها, اخرجي, والمحروم, سألتهم, ويمنيهم, منقلبا, وينطقون,
# Nearest to ومن: ونستفتحها, الصادق, نصبوه, السرياني, حظياتك, بحسن, فجاءت, ويهدي,
# Nearest to ضرب: سخرة, عسيئيل, والمرتعد, أليعام, الماكيريين, ظفر, ويتعد, بالبنين,
# Nearest to شعبا: مطروحين, يدعونك, فليقاتل, مبعدون, تمييزا, تكهن, تحاربها, لرؤساء,
# Nearest to فكانت: لجند, ورزقكم, الرابعة, الساكنين, داريوس, معتنفا, كار, يشقه,
# Nearest to الفصح: فيخدمه, الباكورات, عيد, الفطير, ومشيريك, لعماسا, والمغنون, للبر,
# Nearest to احد: عضوا, فيتقدس, المواعز, وباصر, وقرأت, يفاوضوكم, كيس, تقووه,
# Nearest to مكتوبة: كونتس, والأخيرة, التثبيت, الذلى, أخبار, العدد, وبكرو, أماهي,
# Nearest to هيكل: الخيمة, كصدع, وانهزمت, ليمجدك, لوح, اهان, شاشق, والمشايخ,
# Nearest to كتب: دخولنا, سأتلو, وايرونيمس, شالح, رهبة, يعلل, المواعيد, توكلنا,
# Epoch 19/40 Iteration: 9100 Avg. Training loss: 2.5370 0.4321 sec/batch
# Epoch 19/40 Iteration: 9200 Avg. Training loss: 2.3227 0.4628 sec/batch
# Epoch 19/40 Iteration: 9300 Avg. Training loss: 2.4367 0.4192 sec/batch
# Epoch 19/40 Iteration: 9400 Avg. Training loss: 2.5109 0.4314 sec/batch
# Epoch 20/40 Iteration: 9500 Avg. Training loss: 2.3172 0.3893 sec/batch
# Epoch 20/40 Iteration: 9600 Avg. Training loss: 2.4766 0.3895 sec/batch
# Epoch 20/40 Iteration: 9700 Avg. Training loss: 2.2686 0.4158 sec/batch
# Epoch 20/40 Iteration: 9800 Avg. Training loss: 2.4186 0.4129 sec/batch
# Epoch 20/40 Iteration: 9900 Avg. Training loss: 2.4788 0.4209 sec/batch
# Epoch 21/40 Iteration: 10000 Avg. Training loss: 2.2687 0.4210 sec/batch
# Nearest to أن: وانتظرونا, أشراطها, لحمنا, سئل, فيبني, يشفوه, رشيد, الأعظم,
# Nearest to اليوم: وارتعبت, وحجارته, خاصتهم, تحلني, والفأر, اسطاعوا, تحبلين, سفر,
# Nearest to إسرائيل: نحث, وأشتأول, كناموس, أدركهم, أبذلك, والمشتاق, بعبيد, للشبكتين,
# Nearest to يقول: ولبنيامين, بأسرع, طرقكم, فأحضرها, استبدلوا, ترتاح, زبوب, ضربتكم,
# Nearest to ولكن: بكرك, ليبلو, ومنافع, غاوين, اطرحوا, نعطيه, برأي, ويحبه,
# Nearest to عشر: والعشرين, وعشر, الحادي, قائلالو, للشهر, والثلاثون, أعوزكم, السادس,
# Nearest to إلا: فليعطها, خسرها, اخرجي, منقلبا, ويمنيهم, سألتهم, أذلل, وينطقون,
# Nearest to ومن: ونستفتحها, الصادق, نصبوه, وأحباؤه, بحسن, ويهدي, السرياني, حظياتك,
# Nearest to ضرب: عسيئيل, سخرة, والمرتعد, الماكيريين, أليعام, ويتعد, ظفر, بالبنين,
# Nearest to شعبا: مطروحين, يدعونك, فليقاتل, تمييزا, مبعدون, تكهن, تحاربها, لرؤساء,
# Nearest to فكانت: لجند, ورزقكم, الساكنين, الرابعة, معتنفا, كار, داريوس, أبيطوب,
# Nearest to الفصح: عيد, الباكورات, الفطير, فيخدمه, ومشيريك, والمغنون, للبر, لعماسا,
# Nearest to احد: عضوا, فيتقدس, المواعز, وباصر, وقرأت, تقووه, كيس, انواطا,
# Nearest to مكتوبة: كونتس, والأخيرة, التثبيت, الذلى, أخبار, أماهي, بحبر, العدد,
# Nearest to هيكل: الخيمة, كصدع, ليمجدك, وانهزمت, حفظتهم, والبعيدون, فحياته, لوح,
# Nearest to كتب: دخولنا, وايرونيمس, شالح, سأتلو, رهبة, المواعيد, والجامع, يعلل,
# Epoch 21/40 Iteration: 10100 Avg. Training loss: 2.4281 0.4268 sec/batch
# Epoch 21/40 Iteration: 10200 Avg. Training loss: 2.2261 0.4169 sec/batch
# Epoch 21/40 Iteration: 10300 Avg. Training loss: 2.4117 0.4280 sec/batch
# Epoch 22/40 Iteration: 10400 Avg. Training loss: 2.4132 0.0210 sec/batch
# Epoch 22/40 Iteration: 10500 Avg. Training loss: 2.2489 0.4226 sec/batch
# Epoch 22/40 Iteration: 10600 Avg. Training loss: 2.3817 0.4221 sec/batch
# Epoch 22/40 Iteration: 10700 Avg. Training loss: 2.1571 0.4197 sec/batch
# Epoch 22/40 Iteration: 10800 Avg. Training loss: 2.4092 0.4182 sec/batch
# Epoch 23/40 Iteration: 10900 Avg. Training loss: 2.3692 0.0457 sec/batch
# Epoch 23/40 Iteration: 11000 Avg. Training loss: 2.2291 0.4151 sec/batch
# Nearest to أن: وانتظرونا, أشراطها, سئل, فيبني, لحمنا, يشفوه, لتعبدوه, رشيد,
# Nearest to اليوم: وارتعبت, وحجارته, خاصتهم, تحلني, والفأر, الاسكندر, تحبلين, لتعملها,
# Nearest to إسرائيل: نحث, وأشتأول, كناموس, أبذلك, أدركهم, للشبكتين, بعبيد, للتسعة,
# Nearest to يقول: ولبنيامين, فأحضرها, بأسرع, طرقكم, أعرفكن, ضربتكم, نصيبها, استبدلوا,
# Nearest to ولكن: بكرك, ليبلو, ومنافع, اطرحوا, كمبشر, برأي, عدت, نثقل,
# Nearest to عشر: والعشرين, والثلاثون, الحادي, السادس, للشهر, وعشر, تلميذا, حكمها,
# Nearest to إلا: فليعطها, خسرها, منقلبا, اخرجي, ويمنيهم, الفوز, يبكتني, والمحروم,
# Nearest to ومن: ونستفتحها, الصادق, نصبوه, بحسن, وأحباؤه, تحجر, ويهدي, حظياتك,
# Nearest to ضرب: سخرة, عسيئيل, الماكيريين, ويتعد, والمرتعد, بالتنهد, أليعام, ظفر,
# Nearest to شعبا: مطروحين, يدعونك, تمييزا, فليقاتل, تكهن, مبعدون, تحاربها, ومواسم,
# Nearest to فكانت: لجند, ورزقكم, معتنفا, الرابعة, الساكنين, داريوس, أبيطوب, كار,
# Nearest to الفصح: عيد, الفطير, الباكورات, فيخدمه, ومشيريك, والمغنون, للبر, لعماسا,
# Nearest to احد: عضوا, فيتقدس, المواعز, وباصر, وقرأت, انواطا, تقووه, كيس,
# Nearest to مكتوبة: والأخيرة, كونتس, التثبيت, الذلى, أخبار, بحبر, أماهي, الابكار,
# Nearest to هيكل: الخيمة, كصدع, والبعيدون, حفظتهم, وانهزمت, ليمجدك, فحياته, شاشق,
# Nearest to كتب: وايرونيمس, دخولنا, شالح, سأتلو, يعلل, تؤمرون, والجامع, رهبة,
# Epoch 23/40 Iteration: 11100 Avg. Training loss: 2.3342 0.4295 sec/batch
# Epoch 23/40 Iteration: 11200 Avg. Training loss: 2.1334 0.4221 sec/batch
# Epoch 23/40 Iteration: 11300 Avg. Training loss: 2.3968 0.4179 sec/batch
# Epoch 24/40 Iteration: 11400 Avg. Training loss: 2.3121 0.0620 sec/batch
# Epoch 24/40 Iteration: 11500 Avg. Training loss: 2.2218 0.4177 sec/batch
# Epoch 24/40 Iteration: 11600 Avg. Training loss: 2.2894 0.4445 sec/batch
# Epoch 24/40 Iteration: 11700 Avg. Training loss: 2.0841 0.4551 sec/batch
# Epoch 24/40 Iteration: 11800 Avg. Training loss: 2.3958 0.4223 sec/batch
# Epoch 25/40 Iteration: 11900 Avg. Training loss: 2.2821 0.0876 sec/batch
# Epoch 25/40 Iteration: 12000 Avg. Training loss: 2.2118 0.4282 sec/batch
# Nearest to أن: وانتظرونا, أشراطها, سئل, فيبني, لحمنا, يشفوه, رشيد, تحاكموا,
# Nearest to اليوم: وارتعبت, وحجارته, خاصتهم, تحلني, الاسكندر, والفأر, تحبلين, لتعملها,
# Nearest to إسرائيل: وأشتأول, أبذلك, نحث, كناموس, بعبيد, للشبكتين, أدركهم, للتسعة,
# Nearest to يقول: ولبنيامين, فأحضرها, أعرفكن, نصيبها, بأسرع, طرقكم, للخداممهما, كبائر,
# Nearest to ولكن: ليبلو, بكرك, اطرحوا, نعطيه, كمبشر, ومنافع, برأي, عدت,
# Nearest to عشر: والعشرين, الحادي, السادس, للشهر, قائلالو, وعشر, والثلاثون, تلميذا,
# Nearest to إلا: فليعطها, خسرها, منقلبا, ويمنيهم, الفوز, يبكتني, وينطقون, اخرجي,
# Nearest to ومن: ونستفتحها, نصبوه, الصادق, وأحباؤه, بحسن, تحجر, وعزيزا, ديانتهم,
# Nearest to ضرب: سخرة, عسيئيل, الماكيريين, ويتعد, والمرتعد, بالتنهد, بالبنين, أليعام,
# Nearest to شعبا: فليقاتل, مطروحين, تمييزا, يدعونك, تكهن, مبعدون, ترقصوا, تحاربها,
# Nearest to فكانت: لجند, ورزقكم, معتنفا, وأعاقبها, الرابعة, الروحي, أبيطوب, الساكنين,
# Nearest to الفصح: عيد, الفطير, الباكورات, ومشيريك, فيخدمه, والمغنون, للبر, الجسدي,
# Nearest to احد: عضوا, فيتقدس, المواعز, وباصر, انواطا, وقرأت, تقووه, كيس,
# Nearest to مكتوبة: والأخيرة, كونتس, الذلى, أماهي, التثبيت, بحبر, الابكار, أخبار,
# Nearest to هيكل: الخيمة, كصدع, والبعيدون, حفظتهم, وسينقذني, ليمجدك, فحياته, يشاء,
# Nearest to كتب: وايرونيمس, دخولنا, شالح, سأتلو, والجامع, يقال, رهبة, لاعبين,
# Epoch 25/40 Iteration: 12100 Avg. Training loss: 2.2290 0.4325 sec/batch
# Epoch 25/40 Iteration: 12200 Avg. Training loss: 2.0395 0.4239 sec/batch
# Epoch 25/40 Iteration: 12300 Avg. Training loss: 2.3933 0.4229 sec/batch
# Epoch 26/40 Iteration: 12400 Avg. Training loss: 2.2214 0.1042 sec/batch
# Epoch 26/40 Iteration: 12500 Avg. Training loss: 2.2149 0.4181 sec/batch
# Epoch 26/40 Iteration: 12600 Avg. Training loss: 2.1771 0.4269 sec/batch
# Epoch 26/40 Iteration: 12700 Avg. Training loss: 2.0258 0.4275 sec/batch
# Epoch 26/40 Iteration: 12800 Avg. Training loss: 2.3647 0.4210 sec/batch
# Epoch 27/40 Iteration: 12900 Avg. Training loss: 2.1868 0.1252 sec/batch
# Epoch 27/40 Iteration: 13000 Avg. Training loss: 2.2091 0.4259 sec/batch
# Nearest to أن: سئل, أشراطها, وانتظرونا, فيبني, يشفوه, لحمنا, رشيد, تحاكموا,
# Nearest to اليوم: وارتعبت, خاصتهم, وحجارته, والفأر, تحلني, الاسكندر, تحبلين, المذاود,
# Nearest to إسرائيل: وأشتأول, نحث, أبذلك, بعبيد, للشبكتين, إخوتهم, كناموس, أدركهم,
# Nearest to يقول: ولبنيامين, فأحضرها, نصيبها, طرقكم, أعرفكن, استبدلوا, بأسرع, زبوب,
# Nearest to ولكن: بكرك, اطرحوا, ليبلو, ومنافع, كمبشر, برأي, ولتزهر, عدت,
# Nearest to عشر: والعشرين, الحادي, وطالب, وعشر, السادس, لهاأنت, تلميذا, والثلاثون,
# Nearest to إلا: فليعطها, منقلبا, خسرها, ويمنيهم, الفوز, أذلل, يبكتني, اخرجي,
# Nearest to ومن: ونستفتحها, نصبوه, وأحباؤه, الصادق, تحجر, بحسن, علماء, وعزيزا,
# Nearest to ضرب: سخرة, عسيئيل, الماكيريين, ويتعد, والمرتعد, بالتنهد, ظفر, بالبنين,
# Nearest to شعبا: فليقاتل, مطروحين, تمييزا, تكهن, لرؤساء, يدعونك, ومواسم, مبعدون,
# Nearest to فكانت: لجند, ورزقكم, معتنفا, الروحي, وأعاقبها, مرتبكة, إساءة, ونشأتهم,
# Nearest to الفصح: عيد, الباكورات, الفطير, ومشيريك, فيخدمه, اذلاء, للبر, الجسدي,
# Nearest to احد: عضوا, فيتقدس, المواعز, وباصر, انواطا, وقرأت, يحنوا, كيس,
# Nearest to مكتوبة: والأخيرة, كونتس, الذلى, التثبيت, أماهي, بحبر, أخبار, وبكرو,
# Nearest to هيكل: الخيمة, والبعيدون, كصدع, حفظتهم, وسينقذني, وانهزمت, فحياته, ليمجدك,
# Nearest to كتب: وايرونيمس, دخولنا, شالح, سأتلو, يقال, رهبة, لاعبين, ابائه,
# Epoch 27/40 Iteration: 13100 Avg. Training loss: 2.1484 0.4282 sec/batch
# Epoch 27/40 Iteration: 13200 Avg. Training loss: 1.9835 0.4179 sec/batch
# Epoch 27/40 Iteration: 13300 Avg. Training loss: 2.3312 0.4220 sec/batch
# Epoch 28/40 Iteration: 13400 Avg. Training loss: 2.1542 0.1514 sec/batch
# Epoch 28/40 Iteration: 13500 Avg. Training loss: 2.2070 0.4227 sec/batch
# Epoch 28/40 Iteration: 13600 Avg. Training loss: 2.1343 0.4222 sec/batch
# Epoch 28/40 Iteration: 13700 Avg. Training loss: 1.9364 0.4303 sec/batch
# Epoch 28/40 Iteration: 13800 Avg. Training loss: 2.3699 0.4176 sec/batch
# Epoch 29/40 Iteration: 13900 Avg. Training loss: 2.1061 0.1663 sec/batch
# Epoch 29/40 Iteration: 14000 Avg. Training loss: 2.2036 0.4248 sec/batch
# Nearest to أن: سئل, أشراطها, فيبني, يشفوه, وانتظرونا, كمولود, تحاكموا, لحمنا,
# Nearest to اليوم: وارتعبت, والفأر, خاصتهم, تحلني, وحجارته, لتعملها, الاسكندر, تحبلين,
# Nearest to إسرائيل: وأشتأول, نحث, إخوتهم, للشبكتين, أبذلك, بعبيد, أدركهم, وقتما,
# Nearest to يقول: ولبنيامين, فأحضرها, طرقكم, أعرفكن, زبوب, استبدلوا, نصيبها, فاستشار,
# Nearest to ولكن: بكرك, اطرحوا, ليبلو, ولتزهر, كمبشر, ومنافع, برأي, ينموا,
# Nearest to عشر: والعشرين, وعشر, وطالب, الحادي, والكانون, لشوبائيل, تلميذا, والثلاثون,
# Nearest to إلا: فليعطها, ويمنيهم, منقلبا, خسرها, الفوز, أذلل, وينطقون, اخرجي,
# Nearest to ومن: ونستفتحها, نصبوه, الصادق, وأحباؤه, علماء, بحسن, وعزيزا, حظياتك,
# Nearest to ضرب: سخرة, عسيئيل, ويتعد, الماكيريين, بالتنهد, والمرتعد, ظفر, بالبنين,
# Nearest to شعبا: فليقاتل, تكهن, مطروحين, تمييزا, لرؤساء, ومواسم, يشركن, يدعونك,
# Nearest to فكانت: لجند, معتنفا, ورزقكم, الروحي, وأعاقبها, مرتبكة, إساءة, الرابعة,
# Nearest to الفصح: عيد, الباكورات, الفطير, ومشيريك, الجسدي, والمغنون, اذلاء, فيخدمه,
# Nearest to احد: عضوا, فيتقدس, المواعز, انواطا, وباصر, السامية, كيس, يحنوا,
# Nearest to مكتوبة: والأخيرة, كونتس, الذلى, أماهي, التثبيت, أخبار, بحبر, وبكرو,
# Nearest to هيكل: الخيمة, والبعيدون, وسينقذني, كصدع, حفظتهم, ليمجدك, اهان, وانهزمت,
# Nearest to كتب: وايرونيمس, دخولنا, شالح, سأتلو, والجامع, لاعبين, رهبة, يقال,
# Epoch 29/40 Iteration: 14100 Avg. Training loss: 2.1079 0.4398 sec/batch
# Epoch 29/40 Iteration: 14200 Avg. Training loss: 1.9107 0.4219 sec/batch
# Epoch 29/40 Iteration: 14300 Avg. Training loss: 2.3285 0.4236 sec/batch
# Epoch 30/40 Iteration: 14400 Avg. Training loss: 2.0770 0.1892 sec/batch
# Epoch 30/40 Iteration: 14500 Avg. Training loss: 2.2042 0.4203 sec/batch
# Epoch 30/40 Iteration: 14600 Avg. Training loss: 2.0812 0.4191 sec/batch
# Epoch 30/40 Iteration: 14700 Avg. Training loss: 1.8759 0.4089 sec/batch
# Epoch 30/40 Iteration: 14800 Avg. Training loss: 2.3074 0.4148 sec/batch
# Epoch 31/40 Iteration: 14900 Avg. Training loss: 2.0525 0.2284 sec/batch
# Epoch 31/40 Iteration: 15000 Avg. Training loss: 2.1982 0.4268 sec/batch
# Nearest to أن: سئل, فيبني, يشفوه, أشراطها, وانتظرونا, كمولود, أعني, تحاكموا,
# Nearest to اليوم: وارتعبت, والفأر, الاسكندر, تحلني, لتعملها, خاصتهم, وحجارته, صبي,
# Nearest to إسرائيل: وأشتأول, نحث, للشبكتين, إخوتهم, بعبيد, أبذلك, كناموس, أدركهم,
# Nearest to يقول: ولبنيامين, أعرفكن, فأحضرها, زبوب, طرقكم, بأسرع, كبائر, فاستشار,
# Nearest to ولكن: بكرك, ليبلو, اطرحوا, كمبشر, ولتزهر, ومنافع, برأي, ينموا,
# Nearest to عشر: وطالب, الحادي, والعشرين, والثلاثون, لهاأنت, لشوبائيل, والكانون, وإيليئيل,
# Nearest to إلا: فليعطها, منقلبا, ويمنيهم, خسرها, الفوز, أذلل, يبكتني, سألتهم,
# Nearest to ومن: ونستفتحها, نصبوه, الصادق, وأحباؤه, حظياتك, وعزيزا, بحسن, علماء,
# Nearest to ضرب: سخرة, عسيئيل, الماكيريين, ويتعد, بالتنهد, والمرتعد, أبينوعم, واتته,
# Nearest to شعبا: فليقاتل, تكهن, مطروحين, تمييزا, لرؤساء, ومواسم, يشركن, لمساعديك,
# Nearest to فكانت: لجند, معتنفا, الروحي, ورزقكم, وأعاقبها, مرتبكة, ويفرحالمبتغون, إساءة,
# Nearest to الفصح: عيد, الباكورات, الفطير, ومشيريك, الذبائح, الجسدي, دونك, اذلاء,
# Nearest to احد: عضوا, فيتقدس, المواعز, انواطا, وباصر, السامية, وظفر, ليترك,
# Nearest to مكتوبة: والأخيرة, كونتس, الذلى, التثبيت, أماهي, أخبار, بحبر, عبدنغو,
# Nearest to هيكل: والبعيدون, الخيمة, وسينقذني, كصدع, حفظتهم, وانهزمت, فحياته, ليمجدك,
# Nearest to كتب: وايرونيمس, دخولنا, سأتلو, رهبة, لاعبين, شالح, والجامع, ابائه,
# Epoch 31/40 Iteration: 15100 Avg. Training loss: 2.0646 0.4339 sec/batch
# Epoch 31/40 Iteration: 15200 Avg. Training loss: 1.8928 0.4307 sec/batch
# Epoch 31/40 Iteration: 15300 Avg. Training loss: 2.2716 0.4100 sec/batch
# Epoch 32/40 Iteration: 15400 Avg. Training loss: 2.0331 0.2345 sec/batch
# Epoch 32/40 Iteration: 15500 Avg. Training loss: 2.1712 0.4177 sec/batch
# Epoch 32/40 Iteration: 15600 Avg. Training loss: 2.0227 0.4299 sec/batch
# Epoch 32/40 Iteration: 15700 Avg. Training loss: 1.8606 0.4246 sec/batch
# Epoch 32/40 Iteration: 15800 Avg. Training loss: 2.2762 0.4215 sec/batch
# Epoch 33/40 Iteration: 15900 Avg. Training loss: 2.0052 0.2389 sec/batch
# Epoch 33/40 Iteration: 16000 Avg. Training loss: 2.1810 0.4278 sec/batch
# Nearest to أن: فيبني, سئل, يشفوه, أشراطها, أعني, كمولود, رشيد, وانتظرونا,
# Nearest to اليوم: وارتعبت, والفأر, لتعملها, الاسكندر, وحجارته, تحبلين, صبي, تحلني,
# Nearest to إسرائيل: وأشتأول, بعبيد, نحث, إخوتهم, أبذلك, كناموس, للشبكتين, للتسعة,
# Nearest to يقول: ولبنيامين, فأحضرها, نصيبها, طرقكم, فاستشار, زبوب, أعرفكن, كبائر,
# Nearest to ولكن: بكرك, اطرحوا, ليبلو, كمبشر, برأي, غدران, ولتزهر, ومنافع,
# Nearest to عشر: وطالب, الحادي, وإيليئيل, والعشرين, لهاأنت, تلميذا, والثلاثون, والكانون,
# Nearest to إلا: فليعطها, منقلبا, خسرها, وينطقون, الفوز, يبكتني, أذلل, ويمنيهم,
# Nearest to ومن: ونستفتحها, نصبوه, وأحباؤه, الصادق, من, حظياتك, وعزيزا, ديانتهم,
# Nearest to ضرب: سخرة, عسيئيل, ويتعد, الماكيريين, بالتنهد, والمرتعد, للرأس, وضرب,
# Nearest to شعبا: فليقاتل, تكهن, تمييزا, مطروحين, لرؤساء, ومواسم, يشركن, يدعونك,
# Nearest to فكانت: لجند, معتنفا, الروحي, مرتبكة, ورزقكم, وأعاقبها, ونشأتهم, الرابعة,
# Nearest to الفصح: عيد, الفطير, الباكورات, ومشيريك, الذبائح, اذلاء, والمغنون, الجسدي,
# Nearest to احد: عضوا, فيتقدس, المواعز, وباصر, انواطا, وظفر, اخذوا, السامية,
# Nearest to مكتوبة: والأخيرة, كونتس, الذلى, التثبيت, عبدنغو, أماهي, بحبر, أخبار,
# Nearest to هيكل: والبعيدون, الخيمة, حفظتهم, كصدع, اهان, وسينقذني, فحياته, وانهزمت,
# Nearest to كتب: وايرونيمس, دخولنا, سأتلو, والجامع, رهبة, لاعبين, يقال, ابائه,
# Epoch 33/40 Iteration: 16100 Avg. Training loss: 1.9905 0.4253 sec/batch
# Epoch 33/40 Iteration: 16200 Avg. Training loss: 1.8595 0.4164 sec/batch
# Epoch 33/40 Iteration: 16300 Avg. Training loss: 2.2589 0.4293 sec/batch
# Epoch 34/40 Iteration: 16400 Avg. Training loss: 1.9570 0.2737 sec/batch
# Epoch 34/40 Iteration: 16500 Avg. Training loss: 2.1729 0.4220 sec/batch
# Epoch 34/40 Iteration: 16600 Avg. Training loss: 1.9536 0.4244 sec/batch
# Epoch 34/40 Iteration: 16700 Avg. Training loss: 1.8895 0.4201 sec/batch
# Epoch 34/40 Iteration: 16800 Avg. Training loss: 2.2357 0.4207 sec/batch
# Epoch 35/40 Iteration: 16900 Avg. Training loss: 1.9104 0.2906 sec/batch
# Epoch 35/40 Iteration: 17000 Avg. Training loss: 2.1686 0.4269 sec/batch
# Nearest to أن: فيبني, سئل, يشفوه, أشراطها, أعني, كمولود, رشيد, تحيي,
# Nearest to اليوم: الاسكندر, وارتعبت, والفأر, لتعملها, صبي, وحجارته, تحبلين, ويطالب,
# Nearest to إسرائيل: وأشتأول, نحث, بعبيد, إخوتهم, أبذلك, للشبكتين, أدركهم, حدلاي,
# Nearest to يقول: ولبنيامين, نصيبها, فأحضرها, أشفيك, أعرفكن, وصرخا, مشتغل, زبوب,
# Nearest to ولكن: بكرك, وطب, اطرحوا, برأي, كمبشر, يستحقني, آبار, ينموا,
# Nearest to عشر: الحادي, وطالب, والكانون, لهاأنت, وإيليئيل, والعشرين, تلميذا, لشوبائيل,
# Nearest to إلا: فليعطها, منقلبا, خسرها, ويمنيهم, حسبانا, أذلل, يبكتني, الفوز,
# Nearest to ومن: ونستفتحها, نصبوه, وأحباؤه, الصادق, من, حظياتك, ديانتهم, تحجر,
# Nearest to ضرب: سخرة, عسيئيل, ويتعد, الماكيريين, بالتنهد, وضرب, يلاحظ, للرأس,
# Nearest to شعبا: فليقاتل, تكهن, لرؤساء, مطروحين, تمييزا, ومواسم, يشركن, لمساعديك,
# Nearest to فكانت: لجند, معتنفا, الروحي, ورزقكم, مرتبكة, وأعاقبها, ويفرحالمبتغون, إساءة,
# Nearest to الفصح: عيد, الفطير, الباكورات, ومشيريك, الذبائح, المن, اذلاء, والمغنون,
# Nearest to احد: عضوا, فيتقدس, المواعز, انواطا, اخذوا, وباصر, وظفر, السامية,
# Nearest to مكتوبة: والأخيرة, كونتس, الذلى, أماهي, التثبيت, عبدنغو, مدرس, بحبر,
# Nearest to هيكل: والبعيدون, الخيمة, حفظتهم, كصدع, وسينقذني, ليمجدك, اهب, اهان,
# Nearest to كتب: وايرونيمس, سأتلو, دخولنا, والجامع, رهبة, لاعبين, يقال, تؤمرون,
# Epoch 35/40 Iteration: 17100 Avg. Training loss: 1.9347 0.4363 sec/batch
# Epoch 35/40 Iteration: 17200 Avg. Training loss: 1.9257 0.4204 sec/batch
# Epoch 35/40 Iteration: 17300 Avg. Training loss: 2.2404 0.4204 sec/batch
# Epoch 36/40 Iteration: 17400 Avg. Training loss: 1.8948 0.3174 sec/batch
# Epoch 36/40 Iteration: 17500 Avg. Training loss: 2.1270 0.4180 sec/batch
# Epoch 36/40 Iteration: 17600 Avg. Training loss: 1.9047 0.4150 sec/batch
# Epoch 36/40 Iteration: 17700 Avg. Training loss: 1.9446 0.4271 sec/batch
# Epoch 36/40 Iteration: 17800 Avg. Training loss: 2.1847 0.4249 sec/batch
# Epoch 37/40 Iteration: 17900 Avg. Training loss: 1.9033 0.3367 sec/batch
# Epoch 37/40 Iteration: 18000 Avg. Training loss: 2.1027 0.4236 sec/batch
# Nearest to أن: فيبني, يشفوه, سئل, أشراطها, أعني, كمولود, ثوداس, رشيد,
# Nearest to اليوم: الاسكندر, صبي, والفأر, لتعملها, وارتعبت, وحجارته, تحبلين, تحلني,
# Nearest to إسرائيل: بعبيد, نحث, وأشتأول, إخوتهم, أبذلك, للشبكتين, وتراءيا, أدركهم,
# Nearest to يقول: ولبنيامين, زبوب, أشفيك, أعرفكن, بأسرع, طرقكم, فأحضرها, نصيبها,
# Nearest to ولكن: بكرك, وطب, يستحقني, اطرحوا, ينموا, برأي, ليبلو, كمبشر,
# Nearest to عشر: تلميذا, وطالب, الحادي, لهاأنت, وإيليئيل, وعتاي, والكانون, والعشرين,
# Nearest to إلا: فليعطها, خسرها, منقلبا, وينطقون, ويمنيهم, واردها, أذلل, الفوز,
# Nearest to ومن: نصبوه, ونستفتحها, وأحباؤه, من, فمن, الصادق, ديانتهم, أفحكم,
# Nearest to ضرب: سخرة, ويتعد, بالتنهد, الماكيريين, عسيئيل, للرأس, أبينوعم, وضرب,
# Nearest to شعبا: فليقاتل, تكهن, تمييزا, لرؤساء, مطروحين, ومواسم, يشركن, لمساعديك,
# Nearest to فكانت: لجند, معتنفا, الروحي, ورزقكم, مرتبكة, ويفرحالمبتغون, وأعاقبها, ونشأتهم,
# Nearest to الفصح: عيد, الفطير, الباكورات, ومشيريك, الذبائح, المن, والمغنون, اذلاء,
# Nearest to احد: عضوا, فيتقدس, المواعز, وباصر, انواطا, اخذوا, وظفر, السامية,
# Nearest to مكتوبة: والأخيرة, كونتس, الذلى, أماهي, التثبيت, عبدنغو, الابكار, بحبر,
# Nearest to هيكل: والبعيدون, الخيمة, حفظتهم, ليمجدك, كصدع, وسينقذني, اهب, فحياته,
# Nearest to كتب: وايرونيمس, سأتلو, دخولنا, والجامع, رهبة, لاعبين, يقال, يرتدوا,
# Epoch 37/40 Iteration: 18100 Avg. Training loss: 1.8752 0.4250 sec/batch
# Epoch 37/40 Iteration: 18200 Avg. Training loss: 1.9463 0.4175 sec/batch
# Epoch 37/40 Iteration: 18300 Avg. Training loss: 2.1695 0.4224 sec/batch
# Epoch 38/40 Iteration: 18400 Avg. Training loss: 1.9109 0.3749 sec/batch
# Epoch 38/40 Iteration: 18500 Avg. Training loss: 2.0900 0.4277 sec/batch
# Epoch 38/40 Iteration: 18600 Avg. Training loss: 1.8614 0.4247 sec/batch
# Epoch 38/40 Iteration: 18700 Avg. Training loss: 1.9590 0.4223 sec/batch
# Epoch 38/40 Iteration: 18800 Avg. Training loss: 2.1508 0.4209 sec/batch
# Epoch 39/40 Iteration: 18900 Avg. Training loss: 1.8930 0.3760 sec/batch
# Epoch 39/40 Iteration: 19000 Avg. Training loss: 2.0544 0.4176 sec/batch
# Nearest to أن: فيبني, سئل, يشفوه, أشراطها, كمولود, أعني, ثوداس, رشيد,
# Nearest to اليوم: لتعملها, الاسكندر, والفأر, وارتعبت, تحبلين, صبي, فعلتموه, وحجارته,
# Nearest to إسرائيل: بعبيد, إخوتهم, وأشتأول, نحث, للشبكتين, حدلاي, قووا, ملك,
# Nearest to يقول: ولبنيامين, نصيبها, أعرفكن, بأسرع, زبوب, فأحضرها, أشفيك, طرقكم,
# Nearest to ولكن: بكرك, وطب, يستحقني, ينموا, اطرحوا, كمبشر, آبار, ولتزهر,
# Nearest to عشر: الحادي, وطالب, لهاأنت, والثلاثون, لشوبائيل, والعشرين, وعتاي, والكانون,
# Nearest to إلا: فليعطها, خسرها, وينطقون, أذلل, ومتحيريارب, منقلبا, ويمنيهم, الفوز,
# Nearest to ومن: نصبوه, ونستفتحها, من, وأحباؤه, فمن, الصادق, علماء, حظياتك,
# Nearest to ضرب: سخرة, ويتعد, بالتنهد, عسيئيل, الماكيريين, أبينوعم, وضرب, يلاحظ,
# Nearest to شعبا: فليقاتل, تكهن, تمييزا, لرؤساء, مطروحين, ومواسم, يشركن, لمساعديك,
# Nearest to فكانت: لجند, معتنفا, ورزقكم, مرتبكة, وأعاقبها, الروحي, ويفرحالمبتغون, ونشأتهم,
# Nearest to الفصح: عيد, الفطير, الذبائح, الباكورات, ومشيريك, اذلاء, المن, العاشرفي,
# Nearest to احد: عضوا, فيتقدس, وباصر, المواعز, انواطا, اخذوا, وظفر, كيس,
# Nearest to مكتوبة: والأخيرة, كونتس, الذلى, أماهي, عبدنغو, مدرس, التثبيت, بحبر,
# Nearest to هيكل: والبعيدون, الخيمة, حفظتهم, كصدع, ليمجدك, فحياته, اهب, يئوده,
# Nearest to كتب: وايرونيمس, سأتلو, دخولنا, يسوعكلكم, رهبة, والجامع, يقال, يرتدوا,
# Epoch 39/40 Iteration: 19100 Avg. Training loss: 1.8441 0.4425 sec/batch
# Epoch 39/40 Iteration: 19200 Avg. Training loss: 1.9972 0.4218 sec/batch
# Epoch 39/40 Iteration: 19300 Avg. Training loss: 2.1033 0.4220 sec/batch
# Epoch 40/40 Iteration: 19400 Avg. Training loss: 1.8844 0.4076 sec/batch
# Epoch 40/40 Iteration: 19500 Avg. Training loss: 2.0399 0.4222 sec/batch
# Epoch 40/40 Iteration: 19600 Avg. Training loss: 1.8188 0.4172 sec/batch
# Epoch 40/40 Iteration: 19700 Avg. Training loss: 2.0086 0.4197 sec/batch
# Epoch 40/40 Iteration: 19800 Avg. Training loss: 2.0992 0.4307 sec/batch

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from bokeh.plotting import figure, show, output_file
from bokeh.models import ColumnDataSource, Range1d, LabelSet, Label

# %%
# %time
viz_words = 10000
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

output_notebook()
desc = []
for idx in range(viz_words):
    desc.append(int_to_vocab[idx])
    
list_x = list(embed_tsne[0:viz_words, 0])
list_y = list(embed_tsne[0:viz_words, 1])

source = ColumnDataSource(data=dict(x=list_x, y=list_y, desc=desc)) 
hover = HoverTool(tooltips=[
    ('desc', '@desc'),
])
mapper = LinearColorMapper(palette=plasma(256), low=min(list_y), high=max(list_y))

p = figure(plot_width=1000, plot_height=1000, tools=[hover,"pan,wheel_zoom,box_zoom,reset,resize"], 
           title="Word2Vec")
p.circle('x', 'y', size=10, source=source)

labels = LabelSet(x='x', y='y', text='desc', level='glyph',
              x_offset=5, y_offset=5, source=source, render_mode='canvas')

p.add_layout(labels)
show(p)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 22.4 µs
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0a86106d-1c84-4622-956c-f13f08f7f2c4">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="0ef3b35d-0898-4645-af5d-b94d9d83e2e4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#0ef3b35d-0898-4645-af5d-b94d9d83e2e4").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0ef3b35d-0898-4645-af5d-b94d9d83e2e4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0ef3b35d-0898-4645-af5d-b94d9d83e2e4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a77315e7-a9d3-47e8-a5aa-9ffeda62d20b":{"roots":{"references":[{"attributes":{},"id":"bf54907e-35a4-4fae-90c6-6f6cac0db75e","type":"ToolEvents"},{"attributes":{"callback":null,"plot":{"id":"b7602fcf-d186-46f9-9e18-76d7203ea03c","subtype":"Figure","type":"Plot"},"tooltips":[["desc","@desc"]]},"id":"7a215488-90a1-4056-bb92-9d83c2d7e456","type":"HoverTool"},{"attributes":{"plot":{"id":"b7602fcf-d186-46f9-9e18-76d7203ea03c","subtype":"Figure","type":"Plot"}},"id":"f173f84e-3414-4273-915b-5d3240cd6512","type":"PanTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"1cea9f5b-d20b-4b78-ad46-f84ad5790c88","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"b7602fcf-d186-46f9-9e18-76d7203ea03c","subtype":"Figure","type":"Plot"},"ticker":{"id":"60c77151-b8c0-4c20-888a-fae37612b864","type":"BasicTicker"}},"id":"e271e329-ad9d-49b7-a7ae-1da1344ab3e6","type":"Grid"},{"attributes":{"plot":null,"text":"Word2Vec"},"id":"90caac74-29b6-4b80-944a-1d35739e6c15","type":"Title"},{"attributes":{"callback":null},"id":"087d26b5-062f-4894-92cb-ee2c8709df15","type":"DataRange1d"},{"attributes":{"formatter":{"id":"dd586683-7a25-4fb7-be34-7735eb9caa0d","type":"BasicTickFormatter"},"plot":{"id":"b7602fcf-d186-46f9-9e18-76d7203ea03c","subtype":"Figure","type":"Plot"},"ticker":{"id":"60c77151-b8c0-4c20-888a-fae37612b864","type":"BasicTicker"}},"id":"5691f035-48be-40a5-8534-a5b0393ba84f","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7af4e647-ca1c-404c-a433-08349d4dd368","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"b7602fcf-d186-46f9-9e18-76d7203ea03c","subtype":"Figure","type":"Plot"}},"id":"7a7696d1-df6f-42c0-840c-07d64586b330","type":"WheelZoomTool"},{"attributes":{},"id":"dd586683-7a25-4fb7-be34-7735eb9caa0d","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","desc","y"],"data":{"desc":["\u0645\u0646","\u0641\u064a","\u0625\u0644\u0649","\u0627\u0644\u0631\u0628","\u0639\u0644\u0649","\u0644\u0627","\u0627\u0644\u0644\u0647","\u0643\u0644","\u0623\u0646","\u0627\u0644\u0630\u064a","\u0648\u0644\u0627","\u0645\u0627","\u0642\u062f","\u0625\u0633\u0631\u0627\u0626\u064a\u0644","\u0627\u0644\u0630\u064a\u0646","\u0647\u0630\u0627","\u0625\u0646","\u0627\u0644\u0623\u0631\u0636","\u0647\u0648","\u064a\u0627","\u0627\u0644\u062a\u064a","\u0643\u0627\u0646","\u0644\u0647","\u0644\u0645","\u0639\u0646","\u0627\u0644\u0645\u0644\u0643","\u0641\u0642\u0627\u0644","\u062b\u0645","\u0642\u0627\u0644","\u0648","\u0623\u064a\u0636\u0627","\u0644\u0623\u0646","\u062c\u0645\u064a\u0639","\u0628\u064a\u062a","\u0628\u0647","\u0623\u0646\u0627","\u0630\u0644\u0643","\u0648\u0645\u0646","\u0644\u0647\u0645","\u0628\u0646","\u0648\u0642\u0627\u0644","\u0645\u0639","\u0648\u0643\u0627\u0646","\u0628\u0644","\u0645\u0644\u0643","\u062d\u062a\u0649","\u0644\u0623\u0646\u0647","\u0627\u0644\u064a\u0648\u0645","\u0628\u0646\u064a","\u0623\u0648","\u0643\u0645\u0627","\u0627\u0644\u0623\u0635\u062d\u0627\u062d","\u0647\u0630\u0647","\u0627\u0644\u0634\u0639\u0628","\u0639\u0646\u062f","\u0644\u0643\u0645","\u0647\u0643\u0630\u0627","\u0644\u064a","\u064a\u0647\u0648\u0630\u0627","\u0627\u0644\u0649","\u062f\u0627\u0648\u062f","\u0628\u0639\u062f","\u0627\u0646","\u0648\u0643\u0644","\u0645\u0648\u0633\u0649","\u0648\u0627\u062d\u062f","\u0648\u0644\u0645","\u0625\u0644\u0627","\u0639\u0644\u064a\u0647","\u0647\u0646\u0627\u0643","\u064a\u0643\u0648\u0646","\u0648\u0645\u0627","\u0631\u0628","\u064a\u0633\u0648\u0639","\u0623\u0646\u062a","\u0623\u0645\u0627\u0645","\u0625\u0630\u0627","\u0648\u0623\u06 ...
