# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %config IPCompleter.greedy=True

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Jun  1 02:33:11 2018

@author: mohammed-PC
"""
from id import *
from matplotlib import pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Front Side Test

# %% [markdown]
# ## Test #1

# %%
#if __name__== "__main__":
newOp = ID("id0.jpg","id01.jpg")
#Select the card 4 corners
face_img = newOp.crop_points(newOp.face_img)
#Crop the card areas
front_img_parts = newOp.crop_front(face_img  , scale=80)
#Check if there's a human face 
is_id_card = newOp.is_face_card(front_img_parts)
#Extract the ID Data (ID Number)
if is_id_card:
    face_data = newOp.extract_front_data(front_img_parts)
    newOp.show_face_result(face_data)
    plt.show()
else:
    print("this is not Egyptian ID card")
# Out:
# ## Environment
# OS: Linux 4.4.0-127-generic x64bit
# Keras Version: 2.1.6
# TensorFlow Version: 1.8.0
# Opencv Version: 3.2.0
# Front Side Resolution:  (2387, 3774, 3)
# Back Side Resolution:  (1151, 1830, 3)
#
# Project Variables and Instances are Loaded successfully
# New Front Side Scaled Resolution: 440, 688
# Number of faces detected: 1
# 14
# [2, 9, 2, 0, 1, 2, 3, 1, 2, 0, 1, 8, 7, 9]
# ===================Front=====================
# ID NUMBER:  [2, 9, 2, 0, 1, 2, 3, 1, 2, 0, 1, 8, 7, 9]

# %% [markdown]
# # Back Test

# %%
#Select the card 4 corners
bc_img = newOp.crop_points(newOp.back_img)
#Crop the card areas
back_img_parts = newOp.crop_back(bc_img , scale=80)
## ??
is_id_card = True #is_back_card(back_img_parts)
#Extract the ID Data (ID Number and Expiry Date)
if is_id_card:
    back_data = newOp.extract_back_data(back_img_parts)
    newOp.show_back_result(back_data)
else:
    print("this is not Egyptian ID card")
    
newOp.store_csv({**face_data,**back_data})
# Out:
# New Back Side Scaled Resolution: 440, 688
#
# 14
# [2, 9, 2, 0, 1, 2, 3, 1, 2, 0, 1, 8, 1, 9]
# ===================Back======================
# ID NUMBER:  [2, 9, 2, 0, 1, 2, 3, 1, 2, 0, 1, 8, 1, 9]
